# %% [markdown]
# # Part and Parcel: *Predicting North American Freight Costs with Supervised Machine Learning*
#
#
# ### Capstone Project - Machine Learning Report
# *Kimberly Kaufman*
# *August 17, 2019*
#
# ---
#
# ### Abstract
#
# Despite the continuous growth of ebooks over the past decade, the publishing industry continues to fulfill a significant demand for physical, printed books. The cost of distributing print books can vary structurally based on factors such as fixed vs variable, owned vs 3PL, and other differing permutations of distribution cost models. But one significant distribution cost that is relatively constant for all publishers is the cost of freight.
#
# At Wiley, freight costs for North American outbound volume alone can cost millions annually in USD. Although the current methods used to model these costs have been sufficient for financial planning purposes, there is most certainly room for improvement. Previous forecasts have been derived from very basic time series modeling, but we have not yet attempted to apply machine learning to improve our accuracy.
#
# This project aims to predict the freight cost of physical book fulfillment (on both an individual shipment level and an aggregate level) by using supervised machine learning methods on a year’s worth of supply chain data out of our North American distribution center. By implementing a more complex modeling approach, we hope to improve our forecasting accuracy as well as gain better visibility into the main drivers of our costs.
#
# For more details on this project, see the <a href="https://github.com/kaufkauf/Capstone-Project-Intermediate">GitHub repository</a>.

# %% [markdown]
# ### Data Wrangling Recap

# %%
import pandas as pd
import numpy as np

# set working directory & read in files
wd = 'C:/Users/kkaufman/Documents/Data Sci/Intermediate/Freight model/'
vol1 = pd.read_csv(wd + 'FY19outboundv2 - Q1.csv', low_memory=False)
vol2 = pd.read_csv(wd + 'FY19outboundv2 - Q2.csv', low_memory=False)
vol3 = pd.read_csv(wd + 'FY19outboundv2 - Q3.csv', low_memory=False)
vol4 = pd.read_csv(wd + 'FY19outboundv2 - Q4.csv', low_memory=False)
vol = vol1.append([vol2,vol3,vol4])
missfts = pd.read_csv(wd + 'FY19missingfreight.csv', low_memory=False)
freight = pd.read_csv(wd + 'FY19freightcharges2.csv', low_memory=False) 

# new updates: fill in missing freight types
vol['SHIP_METHOD'] = vol['SHIP_METHOD'].str.strip()
vol = pd.merge(left=vol, right=missfts, how='left', left_on=['SHIP_METHOD'], right_on=['SHIP_METHOD'],copy=False)
vol['FREIGHT_TYPE'] = vol['FREIGHT_TYPE'].fillna(vol['FREIGHT TYPE'])
vol = vol.drop(columns=['STYLE CODE','FREIGHT TYPE'],axis=1)

# other data wrangling steps:
# remove trailing spaces from categoricals:
vol['SHIP_COUNTRY_NAME'] = vol['SHIP_COUNTRY_NAME'].str.title().str.strip().fillna('Unknown')
vol['FREIGHT_TYPE'] = vol['FREIGHT_TYPE'].str.strip()
# cap/floor book weight outliers at 5th/95th percentiles
vol['BOOK_WEIGHT'] = np.where(vol['BOOK_WEIGHT'] < vol['BOOK_WEIGHT'].quantile(.05), vol['BOOK_WEIGHT'].quantile(.05), vol['BOOK_WEIGHT'])
vol['BOOK_WEIGHT'] = np.where(vol['BOOK_WEIGHT'] > vol['BOOK_WEIGHT'].quantile(.95), vol['BOOK_WEIGHT'].quantile(.95), vol['BOOK_WEIGHT'])

# pivot volume data based on invoice number & convert to dataframe
idxcols = ['CJDAT1','IHINDT','IHAEDT','INVOICENO','COLLECT_METHOD','CARRIER_CODE','PRIORITY_CODE','SHIP_METHOD','FREIGHT_TYPE','SHIP_COUNTRY_NAME','MARKET_OUTLET']
valcols = ['ISBN10','TOTAL_UNITS','TOTAL_PALLETS','TOTAL_CARTONS','TOTAL_LOOSE','BOOK_WEIGHT']
dfvol = pd.pivot_table(vol, index=idxcols, columns=['GLOBAL_BUSINESS'], values=valcols, 
                       aggfunc={('ISBN10') : len,
                                ('TOTAL_UNITS') : sum,
                                ('TOTAL_PALLETS') : sum,
                                ('TOTAL_CARTONS') : sum,
                                ('TOTAL_LOOSE') : sum,
                                ('BOOK_WEIGHT') : sum}, 
                                fill_value=0)
dfvol = pd.DataFrame(dfvol)
dfvol.reset_index(inplace=True)

# remove multilevel column index & replace with concatenated column names using list comprehension
cols = [str.strip(str.replace((key + ' ' + value),'ISBN10','TOTAL_LINES')) for key, value in dfvol.columns]
dfvol.columns = dfvol.columns.get_level_values(0)
dfvol.columns = cols

# add columns for carton weight & totals
dfvol['CARTON_WEIGHT Agency'] = dfvol['BOOK_WEIGHT Agency']*dfvol['TOTAL_UNITS Agency']
dfvol['CARTON_WEIGHT Education'] = dfvol['BOOK_WEIGHT Education']*dfvol['TOTAL_UNITS Education']
dfvol['CARTON_WEIGHT Reference'] = dfvol['BOOK_WEIGHT Reference']*dfvol['TOTAL_UNITS Reference']
dfvol['CARTON_WEIGHT Test Prep'] = dfvol['BOOK_WEIGHT Test Prep']*dfvol['TOTAL_UNITS Test Prep']
dfvol['CARTON_WEIGHT Trade'] = dfvol['BOOK_WEIGHT Trade']*dfvol['TOTAL_UNITS Trade']
dfvol['TOTAL CARTONS Total'] = dfvol['TOTAL_CARTONS Agency']+dfvol['TOTAL_CARTONS Education']+dfvol['TOTAL_CARTONS Reference']+dfvol['TOTAL_CARTONS Test Prep']+dfvol['TOTAL_CARTONS Trade']
dfvol['TOTAL LOOSE Total'] = dfvol['TOTAL_LOOSE Agency']+dfvol['TOTAL_LOOSE Education']+dfvol['TOTAL_LOOSE Reference']+dfvol['TOTAL_LOOSE Test Prep']+dfvol['TOTAL_LOOSE Trade']
dfvol['TOTAL PALLETS Total']= dfvol['TOTAL_PALLETS Agency']+dfvol['TOTAL_PALLETS Education']+dfvol['TOTAL_PALLETS Reference']+dfvol['TOTAL_PALLETS Test Prep']+dfvol['TOTAL_PALLETS Trade']
dfvol['TOTAL UNITS Total'] = dfvol['TOTAL_UNITS Agency']+dfvol['TOTAL_UNITS Education']+dfvol['TOTAL_UNITS Reference']+dfvol['TOTAL_UNITS Test Prep']+dfvol['TOTAL_UNITS Trade']
dfvol['CARTON_WEIGHT Total'] = dfvol['CARTON_WEIGHT Agency']+dfvol['CARTON_WEIGHT Education']+dfvol['CARTON_WEIGHT Reference']+dfvol['CARTON_WEIGHT Test Prep']+dfvol['CARTON_WEIGHT Trade']

# join vol data to freight data
dffreight = freight[['INVNUMBER','INTDATE','TOTALCHARGE']]
df1 = pd.merge(left=dfvol, right=dffreight, how='left', left_on=['INVOICENO','CJDAT1'], right_on=['INVNUMBER','INTDATE'],copy=False)
df1['TOTALCHARGE'] = df1['TOTALCHARGE'].fillna(0)
df1 = df1.drop(columns=['INVNUMBER','INTDATE'],axis=1)

# Convert dates to dates & add monthly fields
df1['SHIP_MONTH'] = df1['IHAEDT']+19000000
df1['SHIP_MONTH'] = pd.to_datetime(df1['SHIP_MONTH'],format='%Y%m%d')
df1['SHIP_MONTH'] = df1['SHIP_MONTH'].dt.to_period('M')

# Print resulting columns
df1.head()
# Out:
#     CJDAT1   IHINDT   IHAEDT  INVOICENO COLLECT_METHOD CARRIER_CODE  \
# 0        0  1180911  1180911    9477531              Y         UPSN
# 1  1180202  1180202  1180518    6302931              Y         INTN
# 2  1180206  1180206  1180518    6345851              Y         INTN
# 3  1180206  1180206  1180518    6348364              Y         INTN
# 4  1180206  1180206  1180518    6348365              Y         INTN
#
#   PRIORITY_CODE                     SHIP_METHOD             FREIGHT_TYPE  \
# 0            A3  UPS 2-Day Collect - Acct# Req.     Domestic Air Courier
# 1            IX        GP OCEAN FREIGHT COLLECT  Subsidiary Ship Methods
# 2            IX        GP OCEAN FREIGHT COLLECT  Subsidiary Ship Methods
# 3            IX        GP OCEAN FREIGHT COLLECT  Subsidiary Ship Methods
# 4            IX        GP OCEAN FREIGHT COLLECT  Subsidiary Ship Methods
#
#   SHIP_COUNTRY_NAME     ...      CARTON_WEIGHT Reference  \
# 0     United States     ...                          0.0
# 1         Singapore     ...                          0.0
# 2         Singapore     ...                          0.0
# 3         Singapore     ...                          0.0
# 4         Singapore     ...                          0.0
#
#    CARTON_WEIGHT Test Prep  CARTON_WEIGHT Trade  TOTAL CARTONS Total  \
# 0                      0.0                 0.00                    0
# 1                      0.0               336.00                    0
# 2                      0.0               216.00                    0
# 3                    688.0                 0.00                   10
# 4                      0.0              1500.24                    0
#
#    TOTAL LOOSE Total  TOTAL PALLETS Total  TOTAL UNITS Total  \
# 0                  2                    0                  2
# 1                 20                    0                 20
# 2                 10                    0                 10
# 3                  0                    0                 10
# 4                  5                    0                 19
#
#    CARTON_WEIGHT Total  TOTALCHARGE  SHIP_MONTH
# 0                25.60          0.0     2018-09
# 1               336.00          0.0     2018-05
# 2               216.00          0.0     2018-05
# 3               688.00          0.0     2018-05
# 4              1500.24          0.0     2018-05
#
# [5 rows x 53 columns]

# %% [markdown]
# ### Machine Learning Model
#
# #### Basic Linear Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# Generate dummy variables
df2 = pd.DataFrame(pd.get_dummies(df1))

# Test/train split at 80% train, 20% test
X = df2.drop('TOTALCHARGE',axis=1).values
y = df2['TOTALCHARGE'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=24)

# Fit & predict the model
linreg = linear_model.LinearRegression()
linreg.fit(X_train, y_train)
y_pred = linreg.predict(X_test)
print('Accuracy rate for all variables =',linreg.score(X_test, y_test))
# Out:
# Accuracy rate for all variables = 0.30688349045168706

# %%
print("Coefficient mean:",np.mean(linreg.coef_))
print("Coefficient median:",np.median(linreg.coef_))
print("Coefficient minimum:",np.min(linreg.coef_))
print("Coefficient maxmimum:",np.max(linreg.coef_))
print("")
print("Model Coefficients:")
cols = df2.drop('TOTALCHARGE',axis=1)
for idx, col_name in enumerate(cols.columns):
    print("The coefficient for {} is {}".format(col_name, linreg.coef_[0][idx]))
# Out:
# Coefficient mean: -1664.6196404036903
# Coefficient median: -2.769947802560612
# Coefficient minimum: -173810.36219645606
# Coefficient maxmimum: 173810.36200227842
#
# Model Coefficients:
# The coefficient for CJDAT1 is -8.812423315004548e-07
# The coefficient for IHINDT is 0.00013982722217049633
# The coefficient for IHAEDT is -0.03256571710014551
# The coefficient for INVOICENO is -5.868981982682145e-09
# The coefficient for MARKET_OUTLET is 0.006142667896893709
# The coefficient for BOOK_WEIGHT Agency is 0.03888845704519877
# The coefficient for BOOK_WEIGHT Education is 0.02465178990716975
# The coefficient for BOOK_WEIGHT Reference is 0.008336065059364264
# The coefficient for BOOK_WEIGHT Test Prep is -0.07456669971337625
# The coefficient for BOOK_WEIGHT Trade is 0.017748537533465912
# The coefficient for TOTAL_LINES Agency is -0.31864280694916214
# The coefficient for TOTAL_LINES Education is -1.3493887809464733
# The coefficient for TOTAL_LINES Reference is 0.035090496212034444
# The coefficient for TOTAL_LINES Test Prep is -1.1167881126275312
# The coefficient for TOTAL_LINES Trade is -0.33521536849829076
# The coefficient for TOTAL_CARTONS Agency is 721.0707691304123
# The coefficient for TOTAL_CARTONS Education is 722.0443718189174
# The coefficient for TOTAL_CARTONS Reference is 723.1271983823721
# The coefficient for TOTAL_CARTONS Test Prep is 723.7232950492681
# The coefficient for TOTAL_CARTONS Trade is 722.0038867808677
# The coefficient for TOTAL_LOOSE Agency is -11.945839798347892
# The coefficient for TOTAL_LOOSE Education is -11.60408319636142
# The coefficient for TOTAL_LOOSE Reference is -11.660899090156738
# The coefficient for TOTAL_LOOSE Test Prep is -9.214860089993406
# The coefficient for TOTAL_LOOSE Trade is -11.72733862545027
# The coefficient for TOTAL_PALLETS Agency is 104.19374786195957
# The coefficient for TOTAL_PALLETS Education is -80.7732805711651
# The coefficient for TOTAL_PALLETS Reference is 4.232428756457528
# The coefficient for TOTAL_PALLETS Test Prep is -60.65803341199992
# The coefficient for TOTAL_PALLETS Trade is -70.62032484909149
# The coefficient for TOTAL_UNITS Agency is -8.371770445744835
# The coefficient for TOTAL_UNITS Education is -8.411659787294392
# The coefficient for TOTAL_UNITS Reference is -8.486486052864448
# The coefficient for TOTAL_UNITS Test Prep is -8.371191946520378
# The coefficient for TOTAL_UNITS Trade is -8.424289498669223
# The coefficient for CARTON_WEIGHT Agency is -173810.36201296136
# The coefficient for CARTON_WEIGHT Education is -173810.36197692674
# The coefficient for CARTON_WEIGHT Reference is -173810.36202179122
# The coefficient for CARTON_WEIGHT Test Prep is -173810.36219645606
# The coefficient for CARTON_WEIGHT Trade is -173810.36200399633
# The coefficient for TOTAL CARTONS Total is -722.403762711448
# The coefficient for TOTAL LOOSE Total is 11.696088422296688
# The coefficient for TOTAL PALLETS Total is 50.01798092574492
# The coefficient for TOTAL UNITS Total is 8.456750797529606
# The coefficient for CARTON_WEIGHT Total is 173810.36200227842
# The coefficient for COLLECT_METHOD_N is 49.875268425682314
# The coefficient for COLLECT_METHOD_Y is -49.147799259041896
# The coefficient for CARRIER_CODE_9CLT is 0.282442926127077
# The coefficient for CARRIER_CODE_A&BC is 11.368177524739787
# The coefficient for CARRIER_CODE_AACT is -5.005284732770371
# The coefficient for CARRIER_CODE_ABFS is 2.4803232819855716
# The coefficient for CARRIER_CODE_AWBC is 4.201771386218034
# The coefficient for CARRIER_CODE_BNPU is 2.1872825308618418
# The coefficient for CARRIER_CODE_BRPR is 4.219190699299104
# The coefficient for CARRIER_CODE_BTPU is 5.885313617765909
# The coefficient for CARRIER_CODE_CANF is -1.764393720196791
# The coefficient for CARRIER_CODE_CANP is -35.439606310158915
# The coefficient for CARRIER_CODE_CANS is -48.32233825323202
# The coefficient for CARRIER_CODE_CBNK is 4.960190947144226
# The coefficient for CARRIER_CODE_CEVA is 11.22225331575849
# The coefficient for CARRIER_CODE_CFFO is 4.395279087690201
# The coefficient for CARRIER_CODE_CGCC is -4.017724940721916
# The coefficient for CARRIER_CODE_CGPC is -35.184518682838245
# The coefficient for CARRIER_CODE_CGPP is -66.91702660079557
# The coefficient for CARRIER_CODE_CGTD is -6.170329948550722
# The coefficient for CARRIER_CODE_CMKY is 1.64436702536112
# The coefficient for CARRIER_CODE_COYO is -6.16677591744811
# The coefficient for CARRIER_CODE_CPU  is 10.755363170343637
# The coefficient for CARRIER_CODE_CTII is -7.003507391889318
# The coefficient for CARRIER_CODE_CWCE is -4.714333107919696
# The coefficient for CARRIER_CODE_DAFG is -3.7767144497419722
# The coefficient for CARRIER_CODE_DAYR is 3.135998095714678
# The coefficient for CARRIER_CODE_DHLC is 4.060579445151424
# The coefficient for CARRIER_CODE_ECHO is 4.386238733702944
# The coefficient for CARRIER_CODE_EWCF is -74.33132273574178
# The coefficient for CARRIER_CODE_EXLA is -4.820686642587113
# The coefficient for CARRIER_CODE_FDCC is 13.856226078480919
# The coefficient for CARRIER_CODE_FDEC is 20.126037671873352
# The coefficient for CARRIER_CODE_FDFF is 7.326378382413422
# The coefficient for CARRIER_CODE_FEDX is 15.480381574408984
# The coefficient for CARRIER_CODE_FXFE is 97.34353572014683
# The coefficient for CARRIER_CODE_FXNL is 149.93294167034483
# The coefficient for CARRIER_CODE_GTS  is -2.6755682796087323
# The coefficient for CARRIER_CODE_GTW  is -64.13518300745729
# The coefficient for CARRIER_CODE_HJBT is 0.7966566534463043
# The coefficient for CARRIER_CODE_IGPU is 5.454896831287031
# The coefficient for CARRIER_CODE_INTN is -6.616744304041663
# The coefficient for CARRIER_CODE_LCSL is 13.15870240016561
# The coefficient for CARRIER_CODE_MAIS is 2.2474555770857823
# The coefficient for CARRIER_CODE_NATX is 14.11969558811209
# The coefficient for CARRIER_CODE_NEMF is -4.921868514534663
# The coefficient for CARRIER_CODE_ODFL is -3.0851260338355937
# The coefficient for CARRIER_CODE_PITD is -4.885306821356012
# The coefficient for CARRIER_CODE_PURL is 20.691212961116005
# The coefficient for CARRIER_CODE_QXTI is 1.8585063007694114
# The coefficient for CARRIER_CODE_RBTW is -10.917980644225073
# The coefficient for CARRIER_CODE_RDWY is -7.344285859947752
# The coefficient for CARRIER_CODE_REIM is 1.6568133434310268
# The coefficient for CARRIER_CODE_RLTJ is -4.022363269097388
# The coefficient for CARRIER_CODE_RRUN is -2.0928663528556015
# The coefficient for CARRIER_CODE_RTAL is 5.1583172344458506
# The coefficient for CARRIER_CODE_SAIA is -4.729898244673433
# The coefficient for CARRIER_CODE_SDCR is 4.25404809153631
# The coefficient for CARRIER_CODE_TPQL is -5.674676172595472
# The coefficient for CARRIER_CODE_UPGF is 8.001227909427417
# The coefficient for CARRIER_CODE_UPSC is 20.43204272818122
# The coefficient for CARRIER_CODE_UPSN is 4.86800184182744
# The coefficient for CARRIER_CODE_USPS is -48.515001514383584
# The coefficient for CARRIER_CODE_USXI is -5.743360876495031
# The coefficient for CARRIER_CODE_VITY is 3.7334629300197837
# The coefficient for CARRIER_CODE_XMAR is -7.889148105525121
# The coefficient for CARRIER_CODE_YKPU is 3.706653298428119
# The coefficient for PRIORITY_CODE_A1 is 10.416569299057667
# The coefficient for PRIORITY_CODE_A3 is -11.993538502837582
# The coefficient for PRIORITY_CODE_A4 is -11.667782950206673
# The coefficient for PRIORITY_CODE_G1 is -7.781623571131311
# The coefficient for PRIORITY_CODE_G2 is -5.858951493925971
# The coefficient for PRIORITY_CODE_GS is -4.024564641630057
# The coefficient for PRIORITY_CODE_IS is -7.838310955903062
# The coefficient for PRIORITY_CODE_IX is 37.22294608858332
# The coefficient for PRIORITY_CODE_S  is 12.224839065956717
# The coefficient for SHIP_METHOD_2 DAY UPS FREIGHT COLL is 17.2481500340572
# The coefficient for SHIP_METHOD_A&B Courier from GTW is 12.184556478458651
# The coefficient for SHIP_METHOD_A&B LTL Services from GTW is -2.815440366545137
# The coefficient for SHIP_METHOD_AAA COOPER COLLECT is -5.037282865971342
# The coefficient for SHIP_METHOD_ABF Coll 3rd Party Billing is -13.164729026978224
# The coefficient for SHIP_METHOD_ABF Freight Systems Collect is 15.555820643894544
# The coefficient for SHIP_METHOD_AVERITT EXPRESS is -1.8056407427677899
# The coefficient for SHIP_METHOD_Air Mail International is 4.0243008483368365
# The coefficient for SHIP_METHOD_American Wholesale Book is 3.68607974979502
# The coefficient for SHIP_METHOD_B&N Customer Manifest is 5.104451977911501
# The coefficient for SHIP_METHOD_BAKER & TAYLOR - COMMERCE,GA is 1.5101933881232699
# The coefficient for SHIP_METHOD_BAKER & TAYLOR - MOMENCE, IL is 1.709570919687734
# The coefficient for SHIP_METHOD_BAKER & TAYLOR - RENO, NV is 1.797206857280528
# The coefficient for SHIP_METHOD_BAKER & TAYLOR-BRIDGEWATER,NJ is 1.356809925340625
# The coefficient for SHIP_METHOD_BR PRINTERS - PICKUP is 5.146060526703735
# The coefficient for SHIP_METHOD_C.H. Robinson - Collect is -10.980414627620993
# The coefficient for SHIP_METHOD_CANPAR GROUND is -34.643661029767294
# The coefficient for SHIP_METHOD_CANPAR OVERNIGHT is -23.30727465103074
# The coefficient for SHIP_METHOD_CANPAR Select is -25.231839786262764
# The coefficient for SHIP_METHOD_CCX - Collect is -2.288611072539381
# The coefficient for SHIP_METHOD_CENTRAL TRANSPORT 3RD PARTY is -7.086910111147265
# The coefficient for SHIP_METHOD_CEVA/EGL/FASTAIR 2 DAY COLLECT is 11.313041242938805
# The coefficient for SHIP_METHOD_CORMAKYE TRANSPORT is 1.8158455592339209
# The coefficient for SHIP_METHOD_COYOTE TRUCKING is -5.521994532105016
# The coefficient for SHIP_METHOD_Cabano Kingsway Collect is 3.276209905922328
# The coefficient for SHIP_METHOD_Canadian Freightways Collect is -1.9750851799171991
# The coefficient for SHIP_METHOD_Cengage Generic 3rd Party is -6.589216398434934
# The coefficient for SHIP_METHOD_Cengage Generic Pre Paid is -67.76005651581738
# The coefficient for SHIP_METHOD_Cengage Generic Pre Paid Add is -35.74776082299701
# The coefficient for SHIP_METHOD_Cengage Generic Shipmethod Col is -3.9523988101294765
# The coefficient for SHIP_METHOD_Clarke Transport Collect is 5.043288793307792
# The coefficient for SHIP_METHOD_Consolidated Fastfrate Collect is 4.586102406102159
# The coefficient for SHIP_METHOD_Conway Freight 3rd Party is -2.7730375045596443
# The coefficient for SHIP_METHOD_Customer Own Pickup is -13.917011448573678
# The coefficient for SHIP_METHOD_Customer Pick Up Int'l Air Col is 7.421664629201942
# The coefficient for SHIP_METHOD_Customer Pick Up Two Day Air is 17.0492193897289
# The coefficient for SHIP_METHOD_DAYTON FREIGHT COLLECT is -4.150631187021145
# The coefficient for SHIP_METHOD_DHL Int'l Collect is 4.8245087315483115
# The coefficient for SHIP_METHOD_Day & Ross 3rd Party from GTW is 3.2481190754012297
# The coefficient for SHIP_METHOD_ECHO GLOBAL LOGISTICS is 4.327500884499207
# The coefficient for SHIP_METHOD_ESTES THIRD PARTY is -0.8972629848206961
# The coefficient for SHIP_METHOD_Emery Intl PrePaid is -74.70584014275354
# The coefficient for SHIP_METHOD_Estes Express Collect is -2.9886006847823254
# The coefficient for SHIP_METHOD_ExMark Transportation is -8.200762627456246
# The coefficient for SHIP_METHOD_FDX 1-Day Priority  10:30 PPD is 6.214207475334276
# The coefficient for SHIP_METHOD_FDX 2-Day Standard - 4:30 pm is -61.95056357091883
# The coefficient for SHIP_METHOD_FDX-1 Priority Collect - 10:30 is 0.5292808179294103
# The coefficient for SHIP_METHOD_FDX-2 Standard Collect - 4:30 is 23.395949813395703
# The coefficient for SHIP_METHOD_FED EX FREIGHT COLLECT is -106.97189610018714
# The coefficient for SHIP_METHOD_FEDEX 2DAY COLLECT FROM GTW is 5.581728833255229
# The coefficient for SHIP_METHOD_FEDEX FREIGHT ECONOMY 3RD PTY is -104.33772142245844
# The coefficient for SHIP_METHOD_FEDEX FREIGHT ECONOMY COLLECT is -157.07049840188108
# The coefficient for SHIP_METHOD_FEDEX FREIGHT PPD is 308.3025782255406
# The coefficient for SHIP_METHOD_FEDEX INT'L ECONOMY COLLECT is -8.895938497540445
# The coefficient for SHIP_METHOD_FEDEX National Pre-Paid is 307.3975691748076
# The coefficient for SHIP_METHOD_FEDEX OVERNIGH ECON CANADA is 6.516375727860456
# The coefficient for SHIP_METHOD_FedEx 1-Day Std. 3rd Party is -0.02241496572928
# The coefficient for SHIP_METHOD_FedEx 2-Day Third Party Bill is 22.323073039793485
# The coefficient for SHIP_METHOD_FedEx Int'l Priority Collect is 1.1858551398059034
# The coefficient for SHIP_METHOD_FedEx Int'l Priority Prepaid is 0.6417263007854858
# The coefficient for SHIP_METHOD_FedEx International Economy PP is 16.39553498904668
# The coefficient for SHIP_METHOD_FedEx Next Day 3:00 PM Collect is -0.6250342936681501
# The coefficient for SHIP_METHOD_Federal Express Saver Collect is 21.192944197822275
# The coefficient for SHIP_METHOD_Fedex Ground 3rd Party is 19.80271067639993
# The coefficient for SHIP_METHOD_Fedex Ground Bill Recipient is 59.157794207894206
# The coefficient for SHIP_METHOD_Fedex Ground Collect from GTW is 6.31076341022458
# The coefficient for SHIP_METHOD_Fedex Ground Pre-Paid is -62.5629882372849
# The coefficient for SHIP_METHOD_GP AIR FREIGHT COLLECT is -2.776536878216419
# The coefficient for SHIP_METHOD_GP OCEAN FREIGHT COLLECT is -3.7156086305684526
# The coefficient for SHIP_METHOD_GTS Third Party is -3.3351160612112305
# The coefficient for SHIP_METHOD_GTW Express One Day PPD is -13.081706973511864
# The coefficient for SHIP_METHOD_GTW Express Two Day PPD is -16.657983569457265
# The coefficient for SHIP_METHOD_GTW LTL Prepaid is -26.43050342803365
# The coefficient for SHIP_METHOD_GTW Small Package Ground PPD is -8.091683329534975
# The coefficient for SHIP_METHOD_Ingram Books Customer Pickup is 1.285469255091957
# The coefficient for SHIP_METHOD_Ingram Consol. FT. WAYNE, IN is 0.9052701610293568
# The coefficient for SHIP_METHOD_Ingram Consol. LAVERGNE TN is 1.5518584525092478
# The coefficient for SHIP_METHOD_Ingram Consol. PETERSBRUG is 1.992857996926413
# The coefficient for SHIP_METHOD_Ingram Consol. ROSEBURG is 0.8482647993899263
# The coefficient for SHIP_METHOD_JB HUNT COLLECT is 0.8213351780915009
# The coefficient for SHIP_METHOD_LOOMIS AIR COLLECT is 14.670987670216947
# The coefficient for SHIP_METHOD_LOOMIS GRD COLLECT is -1.5195410815338313
# The coefficient for SHIP_METHOD_MI USPS Parcel Consol. is -19.434652890561416
# The coefficient for SHIP_METHOD_Nationex Ground Collect is 13.977878387368701
# The coefficient for SHIP_METHOD_New England Motor Frt. Collect is -4.956398889584033
# The coefficient for SHIP_METHOD_Old Dominion Freight Collect is -2.766858100561579
# The coefficient for SHIP_METHOD_PUROLATOR 2 DAY AIR COLLECT is 5.014997358086602
# The coefficient for SHIP_METHOD_PUROLATOR GROUND COLLECT is 7.540808294319429
# The coefficient for SHIP_METHOD_Pitt Ohio 3rd Party is -2.3289178865597817
# The coefficient for SHIP_METHOD_Pitt Ohio Collect is -2.653630541897955
# The coefficient for SHIP_METHOD_Priority Mail (USA) is -20.742920305404954
# The coefficient for SHIP_METHOD_Purolator AIR Collect is 7.337065012103411
# The coefficient for SHIP_METHOD_QUIKTRAX INTERMODAL COLLECT is 1.9072291959478118
# The coefficient for SHIP_METHOD_R & L Carriers Collect is -3.8699255203388585
# The coefficient for SHIP_METHOD_REIMER Collect is 1.5724520709539727
# The coefficient for SHIP_METHOD_REIMER TRANSPORT (Maisliner) is 2.617344794170402
# The coefficient for SHIP_METHOD_ROADRUNNER 3rd party is -1.9808415540319513
# The coefficient for SHIP_METHOD_ROSEDALE GROUP is 5.302373035018879
# The coefficient for SHIP_METHOD_SAIA is -4.8492603790879345
# The coefficient for SHIP_METHOD_SAMEDAY RIGHT-O-WAY COLLECT is 4.193746643078588
# The coefficient for SHIP_METHOD_TRANSPLACE COLLECT is -5.906851577128776
# The coefficient for SHIP_METHOD_UPS 1-Day Air is -63.818235445731595
# The coefficient for SHIP_METHOD_UPS 1-Day Collect - Acct# Req. is -0.6684409991569222
# The coefficient for SHIP_METHOD_UPS 2 DAY COLLECT FROM GTW is 14.332965197044018
# The coefficient for SHIP_METHOD_UPS 2-Day Air is -50.19108219088617
# The coefficient for SHIP_METHOD_UPS 2-Day Collect - Acct# Req. is 24.670771993449815
# The coefficient for SHIP_METHOD_UPS 2-Day Puerto Rico Collect is -24.399588120128534
# The coefficient for SHIP_METHOD_UPS 3-Day Air is -56.54371274196484
# The coefficient for SHIP_METHOD_UPS 3-Day Collect Acct.# Req. is 23.858350370627473
# The coefficient for SHIP_METHOD_UPS Canada Ground is -45.45512915563108
# The coefficient for SHIP_METHOD_UPS Canada Ground Collect is 6.4876184149732845
# The coefficient for SHIP_METHOD_UPS Canada Int'l Saver Prepaid is 22.74488297753401
# The coefficient for SHIP_METHOD_UPS FREIGHT COLLECT is -22.03773259526714
# The coefficient for SHIP_METHOD_UPS FREIGHT THIRD PARTY is -16.480963638208213
# The coefficient for SHIP_METHOD_UPS Freight Pre-Paid is 30.87124392638847
# The coefficient for SHIP_METHOD_UPS Ground is -60.23886885972258
# The coefficient for SHIP_METHOD_UPS Ground Collect Acct# Req. is 27.88126902169958
# The coefficient for SHIP_METHOD_UPS Ground Collect Canada is 6.392294824761819
# The coefficient for SHIP_METHOD_UPS Ground Collect Puerto Rico is 48.46183884990481
# The coefficient for SHIP_METHOD_UPS Ground Puerto Rico is -16.201170191822957
# The coefficient for SHIP_METHOD_UPS Int'l Expedited Collect is 15.078804365803814
# The coefficient for SHIP_METHOD_UPS Int'l Express Collect is -4.7516598118497555
# The coefficient for SHIP_METHOD_UPS Next Day Sat. Delivery is 70.78212242963508
# The coefficient for SHIP_METHOD_UPS Puerto Rico 1-Day is 7.543712149089359
# The coefficient for SHIP_METHOD_UPS Puerto Rico 2-Day is 72.65816753923646
# The coefficient for SHIP_METHOD_US EXPRESS COLLECT is -6.06451345317218
# The coefficient for SHIP_METHOD_USPS FIRST CLASS is -15.01002950248609
# The coefficient for SHIP_METHOD_VITRAN TRANSWEST'N EXP COLLECT is 3.838706964269847
# The coefficient for SHIP_METHOD_YRC 3rd Party is 0.8689481169127493
# The coefficient for SHIP_METHOD_YRC COLLECT is -8.25632809705387
# The coefficient for SHIP_METHOD_Yankee Book Consol. is 3.702074576375634
# The coefficient for FREIGHT_TYPE_Consolidations is 3.5161158126550376
# The coefficient for FREIGHT_TYPE_Customer Pick Up is 11.200666012964668
# The coefficient for FREIGHT_TYPE_Domestic Air Courier is 16.79849050934093
# The coefficient for FREIGHT_TYPE_Domestic Air Freight is 17.536596432238778
# The coefficient for FREIGHT_TYPE_Domestic Ground Freight is 25.84194566239372
# The coefficient for FREIGHT_TYPE_Domestic Ground Small Package is -11.558071729050841
# The coefficient for FREIGHT_TYPE_GTW Air Courier is -7.680463247012379
# The coefficient for FREIGHT_TYPE_GTW Ground Freight is 5.384204287748123
# The coefficient for FREIGHT_TYPE_GTW Ground Small Package is -12.715627341087588
# The coefficient for FREIGHT_TYPE_Int'l Air Courier is -7.747785947994268
# The coefficient for FREIGHT_TYPE_Int'l Surface is -38.97767898606996
# The coefficient for FREIGHT_TYPE_Internal Use Only is 5.126716448926203
# The coefficient for FREIGHT_TYPE_Subsidiary Ship Methods is -5.396946274155911
# The coefficient for SHIP_COUNTRY_NAME_Afghanistan is -3.0627225180370052
# The coefficient for SHIP_COUNTRY_NAME_Algeria is -3.467536422208523
# The coefficient for SHIP_COUNTRY_NAME_Antigua & Barbuda is -0.9884729232010255
# The coefficient for SHIP_COUNTRY_NAME_Argentina is -23.403763587988063
# The coefficient for SHIP_COUNTRY_NAME_Aruba is -35.39760182234973
# The coefficient for SHIP_COUNTRY_NAME_Australia is 9.92837700634444
# The coefficient for SHIP_COUNTRY_NAME_Austria is -22.289673280192968
# The coefficient for SHIP_COUNTRY_NAME_Azerbaijan is 0.14488328232525485
# The coefficient for SHIP_COUNTRY_NAME_Bahamas is -60.03180365577069
# The coefficient for SHIP_COUNTRY_NAME_Bahrain is -49.13918717169244
# The coefficient for SHIP_COUNTRY_NAME_Bangladesh is 64.32888094175529
# The coefficient for SHIP_COUNTRY_NAME_Barbados is -20.777758920839375
# The coefficient for SHIP_COUNTRY_NAME_Belarus is -9.57334351761462
# The coefficient for SHIP_COUNTRY_NAME_Belgium is 8.456452304532737
# The coefficient for SHIP_COUNTRY_NAME_Belize is -1.3454748242986247
# The coefficient for SHIP_COUNTRY_NAME_Bermuda is -30.920026775278917
# The coefficient for SHIP_COUNTRY_NAME_Bolivia is -21.27880030276687
# The coefficient for SHIP_COUNTRY_NAME_Botswana is 6.492433910328975
# The coefficient for SHIP_COUNTRY_NAME_Brazil is -7.77353762104043
# The coefficient for SHIP_COUNTRY_NAME_Brunei is -26.04669224156583
# The coefficient for SHIP_COUNTRY_NAME_Bulgaria is -5.250560973894068
# The coefficient for SHIP_COUNTRY_NAME_Cambodia is -9.96522905837209
# The coefficient for SHIP_COUNTRY_NAME_Canada is 19.604496561162744
# The coefficient for SHIP_COUNTRY_NAME_Cayman Islands is 58.48907053569837
# The coefficient for SHIP_COUNTRY_NAME_Chile is 16.877404140981177
# The coefficient for SHIP_COUNTRY_NAME_China is -6.8157601735966455
# The coefficient for SHIP_COUNTRY_NAME_Colombia is 21.175210086789832
# The coefficient for SHIP_COUNTRY_NAME_Costa Rica is 178.98200478765858
# The coefficient for SHIP_COUNTRY_NAME_Croatia is 43.66695246646235
# The coefficient for SHIP_COUNTRY_NAME_Curacao is -52.2972331841059
# The coefficient for SHIP_COUNTRY_NAME_Cyprus is -30.795091904042653
# The coefficient for SHIP_COUNTRY_NAME_Czech Republic is -10.835617722186317
# The coefficient for SHIP_COUNTRY_NAME_Denmark is 3.8189087504181654
# The coefficient for SHIP_COUNTRY_NAME_Dominican Republic is -8.240304652945643
# The coefficient for SHIP_COUNTRY_NAME_Ecuador is 102.19181058708415
# The coefficient for SHIP_COUNTRY_NAME_Egypt is -40.40830874883043
# The coefficient for SHIP_COUNTRY_NAME_El Salvador is 76.82631176810266
# The coefficient for SHIP_COUNTRY_NAME_Estonia is -4.297155140824652
# The coefficient for SHIP_COUNTRY_NAME_Finland is -30.723266072135676
# The coefficient for SHIP_COUNTRY_NAME_Foreign Purchase  (Usa) is -4.2870825021218035
# The coefficient for SHIP_COUNTRY_NAME_France is -18.04307037291344
# The coefficient for SHIP_COUNTRY_NAME_Georgia is -3.192645195333784
# The coefficient for SHIP_COUNTRY_NAME_Germany is -3.6006719689198636
# The coefficient for SHIP_COUNTRY_NAME_Ghana is 1.9214335862051934
# The coefficient for SHIP_COUNTRY_NAME_Greece is -26.824137503995992
# The coefficient for SHIP_COUNTRY_NAME_Greenland is -9.795798895497152
# The coefficient for SHIP_COUNTRY_NAME_Grenada is -51.27001203026713
# The coefficient for SHIP_COUNTRY_NAME_Guadeloupe is -5.806551468207678
# The coefficient for SHIP_COUNTRY_NAME_Guam is 38.1962307148782
# The coefficient for SHIP_COUNTRY_NAME_Guatemala is 466.11838617319427
# The coefficient for SHIP_COUNTRY_NAME_Guernsey is -49.68302530915557
# The coefficient for SHIP_COUNTRY_NAME_Honduras is 54.392607466108714
# The coefficient for SHIP_COUNTRY_NAME_Hong Kong is -11.78535360856548
# The coefficient for SHIP_COUNTRY_NAME_Hungary is -6.652435387896352
# The coefficient for SHIP_COUNTRY_NAME_Iceland is 330.0927937118765
# The coefficient for SHIP_COUNTRY_NAME_India is -1.1342106062682975
# The coefficient for SHIP_COUNTRY_NAME_Indonesia is 28.905233215001466
# The coefficient for SHIP_COUNTRY_NAME_Iran is -6.691385925339109
# The coefficient for SHIP_COUNTRY_NAME_Iraq is 0.0
# The coefficient for SHIP_COUNTRY_NAME_Ireland is -27.85559361555858
# The coefficient for SHIP_COUNTRY_NAME_Israel is -16.302552969725916
# The coefficient for SHIP_COUNTRY_NAME_Italy is -20.66380161841773
# The coefficient for SHIP_COUNTRY_NAME_Jamaica is -33.4987688237425
# The coefficient for SHIP_COUNTRY_NAME_Japan is -10.333678515244204
# The coefficient for SHIP_COUNTRY_NAME_Jersey is 102.39159842625862
# The coefficient for SHIP_COUNTRY_NAME_Jordan is -4.930443212167338
# The coefficient for SHIP_COUNTRY_NAME_Kazakhstan is -7.688872357433039
# The coefficient for SHIP_COUNTRY_NAME_Kenya is -8.933985476596597
# The coefficient for SHIP_COUNTRY_NAME_Kuwait is 30.42121595775516
# The coefficient for SHIP_COUNTRY_NAME_Latvia is -22.09103211479126
# The coefficient for SHIP_COUNTRY_NAME_Lebanon is -24.643052506762597
# The coefficient for SHIP_COUNTRY_NAME_Liberia is 6.4293296374316204
# The coefficient for SHIP_COUNTRY_NAME_Libya is -6.818047118597942
# The coefficient for SHIP_COUNTRY_NAME_Liechtenstein is -5.138076170513127
# The coefficient for SHIP_COUNTRY_NAME_Lithuania is -6.311906681427234
# The coefficient for SHIP_COUNTRY_NAME_Luxembourg is -24.89415371389864
# The coefficient for SHIP_COUNTRY_NAME_Macedonia is -7.563149620011914
# The coefficient for SHIP_COUNTRY_NAME_Malaysia is -89.74827739672926
# The coefficient for SHIP_COUNTRY_NAME_Malta is -38.35966807483517
# The coefficient for SHIP_COUNTRY_NAME_Mauritius is -12.507874672997236
# The coefficient for SHIP_COUNTRY_NAME_Mexico is -26.005511487275466
# The coefficient for SHIP_COUNTRY_NAME_Monaco is -29.80958612881897
# The coefficient for SHIP_COUNTRY_NAME_Mongolia is -0.5095956252757562
# The coefficient for SHIP_COUNTRY_NAME_Morocco is 12.347186471029058
# The coefficient for SHIP_COUNTRY_NAME_Mozambique is 0.0
# The coefficient for SHIP_COUNTRY_NAME_Myanmar is -92.94137774415192
# The coefficient for SHIP_COUNTRY_NAME_Namibia is -129.07967814116853
# The coefficient for SHIP_COUNTRY_NAME_Netherlands is -28.07670950128439
# The coefficient for SHIP_COUNTRY_NAME_New Zealand is -24.78659406345932
# The coefficient for SHIP_COUNTRY_NAME_Nicaragua is 115.82249324876793
# The coefficient for SHIP_COUNTRY_NAME_Nigeria is -22.27159002952939
# The coefficient for SHIP_COUNTRY_NAME_Northern Mariana Islands is 26.487344257726694
# The coefficient for SHIP_COUNTRY_NAME_Norway is -12.541520750876126
# The coefficient for SHIP_COUNTRY_NAME_Oman is -41.12341724577667
# The coefficient for SHIP_COUNTRY_NAME_Pakistan is -43.535381999907685
# The coefficient for SHIP_COUNTRY_NAME_Panama is 202.365491358861
# The coefficient for SHIP_COUNTRY_NAME_Peru is 104.72957868845522
# The coefficient for SHIP_COUNTRY_NAME_Philippines is -21.674447472419867
# The coefficient for SHIP_COUNTRY_NAME_Poland is -4.390583022588667
# The coefficient for SHIP_COUNTRY_NAME_Portugal is -8.800490982110844
# The coefficient for SHIP_COUNTRY_NAME_Puerto Rico is -1.8333675480756402
# The coefficient for SHIP_COUNTRY_NAME_Qatar is -12.64629822301933
# The coefficient for SHIP_COUNTRY_NAME_Romania is 0.24664686465177774
# The coefficient for SHIP_COUNTRY_NAME_Russia is -1.6228480515287358
# The coefficient for SHIP_COUNTRY_NAME_Saint Kitts And Nevis is -45.32522852710465
# The coefficient for SHIP_COUNTRY_NAME_Saint Lucia is -38.01783280347873
# The coefficient for SHIP_COUNTRY_NAME_Saipan is 12.265370558161537
# The coefficient for SHIP_COUNTRY_NAME_Saudi Arabia is -41.06486690683446
# The coefficient for SHIP_COUNTRY_NAME_Senegal is 3.054836901063726
# The coefficient for SHIP_COUNTRY_NAME_Serbia is -55.21310775379843
# The coefficient for SHIP_COUNTRY_NAME_Sierra Leone is -9.598424666841144
# The coefficient for SHIP_COUNTRY_NAME_Singapore is 0.8495570410213164
# The coefficient for SHIP_COUNTRY_NAME_Slovak Republic is -3.91641627346871
# The coefficient for SHIP_COUNTRY_NAME_Slovenia is -5.826310337209473
# The coefficient for SHIP_COUNTRY_NAME_South Africa is -3.4487644380059512
# The coefficient for SHIP_COUNTRY_NAME_South Korea is -9.732482918411616
# The coefficient for SHIP_COUNTRY_NAME_Spain is -13.052781602194269
# The coefficient for SHIP_COUNTRY_NAME_Sri Lanka is -15.394390905780224
# The coefficient for SHIP_COUNTRY_NAME_Swaziland is 5.308845235613742
# The coefficient for SHIP_COUNTRY_NAME_Sweden is -17.408122512835874
# The coefficient for SHIP_COUNTRY_NAME_Switzerland is -10.665253555916097
# The coefficient for SHIP_COUNTRY_NAME_Taiwan is -13.852403009637387
# The coefficient for SHIP_COUNTRY_NAME_Tanzania is 95.43491522949724
# The coefficient for SHIP_COUNTRY_NAME_Thailand is -25.423493083829285
# The coefficient for SHIP_COUNTRY_NAME_Trinidad And Tobago is -40.039105323036175
# The coefficient for SHIP_COUNTRY_NAME_Turkey is -34.19050388690496
# The coefficient for SHIP_COUNTRY_NAME_Uganda is 8.135294281827907
# The coefficient for SHIP_COUNTRY_NAME_Ukraine is 1.6798110556711727
# The coefficient for SHIP_COUNTRY_NAME_United Arab Emirates is -44.011567228220656
# The coefficient for SHIP_COUNTRY_NAME_United Kingdom is 4.002696913655227
# The coefficient for SHIP_COUNTRY_NAME_United States is -2.063501845123431
# The coefficient for SHIP_COUNTRY_NAME_Unknown is -60.507406046942215
# The coefficient for SHIP_COUNTRY_NAME_Uruguay is -21.959957302633597
# The coefficient for SHIP_COUNTRY_NAME_Us Minor Outlying Islands is -95.09849081149213
# The coefficient for SHIP_COUNTRY_NAME_Venezuela is -29.28902673809389
# The coefficient for SHIP_COUNTRY_NAME_Vietnam is 15.938072201994123
# The coefficient for SHIP_COUNTRY_NAME_Virgin Islands (Us) is -45.957438676530494
# The coefficient for SHIP_COUNTRY_NAME_Zambia is -9.370845498342094
# The coefficient for SHIP_COUNTRY_NAME_Zimbabwe is 0.0
# The coefficient for SHIP_MONTH_2018-05 is -114.4172209166428
# The coefficient for SHIP_MONTH_2018-06 is -110.00488725750839
# The coefficient for SHIP_MONTH_2018-07 is -106.28136108644685
# The coefficient for SHIP_MONTH_2018-08 is -103.6181233758196
# The coefficient for SHIP_MONTH_2018-09 is -100.60136835269559
# The coefficient for SHIP_MONTH_2018-10 is -97.30894047748617
# The coefficient for SHIP_MONTH_2018-11 is -94.8827030601402
# The coefficient for SHIP_MONTH_2018-12 is -91.90950716649134
# The coefficient for SHIP_MONTH_2019-01 is 197.70867927105817
# The coefficient for SHIP_MONTH_2019-02 is 200.7936870459698
# The coefficient for SHIP_MONTH_2019-03 is 203.69660444228833
# The coefficient for SHIP_MONTH_2019-04 is 206.48237723208152

# %% [markdown]
# Given several hundred dummy variables, we can take a look ourselves at some of the coefficients for our basic categories to determine which variables might be more important to the model.  There are a lot of insights to this first round of regression training.
#
# Our mean correlation coefficient is -1,664, whereas our median correlation coefficient is -2.76, indicating that there are a lot of extremely negative coefficients skewing our mean.  In terms of the data, this means that there are some outlier coefficients that have a negative correlation, meaning that as these variables go up, our freight cost goes down quite a bit (or, in the case of dummy variables, freight cost is much lower for the dummy variable classification than for other categorical classifications).  Given the data we're working with, this makes sense--our volume data includes a large number of shipments that aren't associated with any freight cost at all, so we can expect a lot of those cost-free shipments to have negative coefficients.
#
# In terms of specifics, the following variable groups appear to have significant coefficients:
# * Total cartons - coefficients ~ -722 for the total, and ~721-723 for each individual business
# * Carton weight - coefficients ~ 173,810 for the total, and -173,810 for each individual business
# * Collect method Y/N - coefficient for Y at 49, coefficient for N at -49
# * Carrier code - coefficients vary
#     + We can see that certain carrier codes are significant, such as CANP & CANS (Canpar/Canadian shipments) at coefficients of -35 and -48, respectively
#     + FEDX, FXFE, FXNL with coefficients of 13, 97, and 149 respectively - these should be significant as I believe they indicate different types of FEDEX carriers
#     + Other significant carrier codes appear to be UPSC, USPS, CGPC, CGPP
# * Priority code - coefficients between -11 and 37
# * Freight type, ship method
# * Certain ship country names
#     + This was a strange one.  Iceland appears to be the highest, at a coefficient of 330, and Namibia appears to be the lowest, at a coefficient of -129.
# * Month of shipment - extremely significant correlations at ~ -100 or ~ +200
#
# This ends up being quite a bit too many coefficients to reasonably interpret by eyeballing them, so we may want to consider some more in-depth regression models that assist with variable selection and add regularization to the mix.

# %% [markdown]
# #### LASSO Regression

# %%
from sklearn.linear_model import Lasso
import matplotlib.pyplot as plt

# Reuse train/test split from previous linear model @ 80/20 train/test

# Train and fit the model
lasso = Lasso(alpha = .001, normalize = True)
lasso.fit(X_train, y_train)
lasso_pred = lasso.predict(X_test)
print('Accuracy rate for all variables in LASSO regression =',lasso.score(X_test, y_test))

# Perform feature selection
lasso_coef = pd.Series(lasso.coef_, index = names)
print('Significant features:')
print(lasso_coef[lasso_coef > 0])
# Out:
# Accuracy rate for all variables in LASSO regression = 0.28521311910007285
# Significant features:
# TOTAL_CARTONS Test Prep                          0.997037
# TOTAL_LOOSE Test Prep                            0.521320
# TOTAL_PALLETS Trade                              0.950338
# TOTAL_UNITS Test Prep                            0.019712
# TOTAL UNITS Total                                0.007686
# COLLECT_METHOD_N                                 3.898855
# CARRIER_CODE_FEDX                               27.476570
# CARRIER_CODE_UPSN                                1.924018
# SHIP_METHOD_FEDEX FREIGHT PPD                  275.742278
# SHIP_METHOD_FEDEX National Pre-Paid            531.027921
# SHIP_METHOD_FedEx Int'l Priority Prepaid        82.817115
# SHIP_METHOD_FedEx International Economy PP       9.711912
# SHIP_METHOD_Fedex Ground Bill Recipient         28.343932
# SHIP_METHOD_UPS 1-Day Air                       20.005259
# SHIP_METHOD_UPS 2-Day Air                       13.113094
# SHIP_METHOD_UPS Canada Int'l Saver Prepaid      61.281285
# SHIP_METHOD_UPS Freight Pre-Paid               131.565107
# SHIP_METHOD_UPS Ground                           3.714169
# SHIP_METHOD_UPS Next Day Sat. Delivery          34.806869
# SHIP_METHOD_UPS Puerto Rico 1-Day               71.070622
# SHIP_METHOD_UPS Puerto Rico 2-Day               90.025421
# FREIGHT_TYPE_Domestic Air Courier                1.195034
# SHIP_COUNTRY_NAME_Costa Rica                   108.225354
# SHIP_COUNTRY_NAME_Guatemala                    293.463904
# SHIP_COUNTRY_NAME_Iceland                      179.427979
# SHIP_COUNTRY_NAME_Panama                       110.049402
# SHIP_COUNTRY_NAME_Peru                          62.453644
# SHIP_COUNTRY_NAME_Puerto Rico                   15.652084
# dtype: float64

# %%
print('Significant variables =',np.array(lasso_coef[lasso_coef > 0].index))
# Out:
# Significant variables = ['TOTAL_CARTONS Test Prep' 'TOTAL_LOOSE Test Prep' 'TOTAL_PALLETS Trade'
#  'TOTAL_UNITS Test Prep' 'TOTAL UNITS Total' 'COLLECT_METHOD_N'
#  'CARRIER_CODE_FEDX' 'CARRIER_CODE_UPSN' 'SHIP_METHOD_FEDEX FREIGHT PPD'
#  'SHIP_METHOD_FEDEX National Pre-Paid'
#  "SHIP_METHOD_FedEx Int'l Priority Prepaid"
#  'SHIP_METHOD_FedEx International Economy PP'
#  'SHIP_METHOD_Fedex Ground Bill Recipient' 'SHIP_METHOD_UPS 1-Day Air'
#  'SHIP_METHOD_UPS 2-Day Air' "SHIP_METHOD_UPS Canada Int'l Saver Prepaid"
#  'SHIP_METHOD_UPS Freight Pre-Paid' 'SHIP_METHOD_UPS Ground'
#  'SHIP_METHOD_UPS Next Day Sat. Delivery'
#  'SHIP_METHOD_UPS Puerto Rico 1-Day' 'SHIP_METHOD_UPS Puerto Rico 2-Day'
#  'FREIGHT_TYPE_Domestic Air Courier          '
#  'SHIP_COUNTRY_NAME_Costa Rica' 'SHIP_COUNTRY_NAME_Guatemala'
#  'SHIP_COUNTRY_NAME_Iceland' 'SHIP_COUNTRY_NAME_Panama'
#  'SHIP_COUNTRY_NAME_Peru' 'SHIP_COUNTRY_NAME_Puerto Rico']
