# %% [markdown]
# # Part and Parcel: *Predicting North American Freight Costs with Supervised Machine Learning*
#
#
# ### Capstone Project - Machine Learning Report
# *Kimberly Kaufman*
# *August 17, 2019*
#
# ---
#
# ### Abstract
#
# Despite the continuous growth of ebooks over the past decade, the publishing industry continues to fulfill a significant demand for physical, printed books. The cost of distributing print books can vary structurally based on factors such as fixed vs variable, owned vs 3PL, and other differing permutations of distribution cost models. But one significant distribution cost that is relatively constant for all publishers is the cost of freight.
#
# At Wiley, freight costs for North American outbound volume alone can cost millions annually in USD. Although the current methods used to model these costs have been sufficient for financial planning purposes, there is most certainly room for improvement. Previous forecasts have been derived from very basic time series modeling, but we have not yet attempted to apply machine learning to improve our accuracy.
#
# This project aims to predict the freight cost of physical book fulfillment (on both an individual shipment level and an aggregate level) by using supervised machine learning methods on a year’s worth of supply chain data out of our North American distribution center. By implementing a more complex modeling approach, we hope to improve our forecasting accuracy as well as gain better visibility into the main drivers of our costs.
#
# For more details on this project, see the <a href="https://github.com/kaufkauf/Capstone-Project-Intermediate">GitHub repository</a>.

# %% [markdown]
# ### Data Wrangling Recap

# %%
import pandas as pd
import numpy as np

# set working directory & read in files
wd = 'C:/Users/kkaufman/Documents/Data Sci/Intermediate/Freight model/'
vol1 = pd.read_csv(wd + 'FY19outboundv2 - Q1.csv', low_memory=False)
vol2 = pd.read_csv(wd + 'FY19outboundv2 - Q2.csv', low_memory=False)
vol3 = pd.read_csv(wd + 'FY19outboundv2 - Q3.csv', low_memory=False)
vol4 = pd.read_csv(wd + 'FY19outboundv2 - Q4.csv', low_memory=False)
vol = vol1.append([vol2,vol3,vol4])
missfts = pd.read_csv(wd + 'FY19missingfreight.csv', low_memory=False)
freight = pd.read_csv(wd + 'FY19freightcharges2.csv', low_memory=False) 

# new updates: fill in missing freight types
vol['SHIP_METHOD'] = vol['SHIP_METHOD'].str.strip()
vol = pd.merge(left=vol, right=missfts, how='left', left_on=['SHIP_METHOD'], right_on=['SHIP_METHOD'],copy=False)
vol['FREIGHT_TYPE'] = vol['FREIGHT_TYPE'].fillna(vol['FREIGHT TYPE'])
vol = vol.drop(columns=['STYLE CODE','FREIGHT TYPE'],axis=1)

# other data wrangling steps:
# remove trailing spaces from categoricals:
vol['SHIP_COUNTRY_NAME'] = vol['SHIP_COUNTRY_NAME'].str.title().str.strip().fillna('Unknown')
vol['FREIGHT_TYPE'] = vol['FREIGHT_TYPE'].str.strip()
# cap/floor book weight outliers at 5th/95th percentiles
vol['BOOK_WEIGHT'] = np.where(vol['BOOK_WEIGHT'] < vol['BOOK_WEIGHT'].quantile(.05), vol['BOOK_WEIGHT'].quantile(.05), vol['BOOK_WEIGHT'])
vol['BOOK_WEIGHT'] = np.where(vol['BOOK_WEIGHT'] > vol['BOOK_WEIGHT'].quantile(.95), vol['BOOK_WEIGHT'].quantile(.95), vol['BOOK_WEIGHT'])

# pivot volume data based on invoice number & convert to dataframe
idxcols = ['CJDAT1','IHINDT','IHAEDT','INVOICENO','COLLECT_METHOD','CARRIER_CODE','PRIORITY_CODE','SHIP_METHOD','FREIGHT_TYPE','SHIP_COUNTRY_NAME','MARKET_OUTLET']
valcols = ['ISBN10','TOTAL_UNITS','TOTAL_PALLETS','TOTAL_CARTONS','TOTAL_LOOSE','BOOK_WEIGHT']
dfvol = pd.pivot_table(vol, index=idxcols, columns=['GLOBAL_BUSINESS'], values=valcols, 
                       aggfunc={('ISBN10') : len,
                                ('TOTAL_UNITS') : sum,
                                ('TOTAL_PALLETS') : sum,
                                ('TOTAL_CARTONS') : sum,
                                ('TOTAL_LOOSE') : sum,
                                ('BOOK_WEIGHT') : sum}, 
                                fill_value=0)
dfvol = pd.DataFrame(dfvol)
dfvol.reset_index(inplace=True)

# remove multilevel column index & replace with concatenated column names using list comprehension
cols = [str.strip(str.replace((key + ' ' + value),'ISBN10','TOTAL_LINES')) for key, value in dfvol.columns]
dfvol.columns = dfvol.columns.get_level_values(0)
dfvol.columns = cols

# add columns for carton weight & totals
dfvol['CARTON_WEIGHT Agency'] = dfvol['BOOK_WEIGHT Agency']*dfvol['TOTAL_UNITS Agency']
dfvol['CARTON_WEIGHT Education'] = dfvol['BOOK_WEIGHT Education']*dfvol['TOTAL_UNITS Education']
dfvol['CARTON_WEIGHT Reference'] = dfvol['BOOK_WEIGHT Reference']*dfvol['TOTAL_UNITS Reference']
dfvol['CARTON_WEIGHT Test Prep'] = dfvol['BOOK_WEIGHT Test Prep']*dfvol['TOTAL_UNITS Test Prep']
dfvol['CARTON_WEIGHT Trade'] = dfvol['BOOK_WEIGHT Trade']*dfvol['TOTAL_UNITS Trade']
dfvol['TOTAL CARTONS Total'] = dfvol['TOTAL_CARTONS Agency']+dfvol['TOTAL_CARTONS Education']+dfvol['TOTAL_CARTONS Reference']+dfvol['TOTAL_CARTONS Test Prep']+dfvol['TOTAL_CARTONS Trade']
dfvol['TOTAL LOOSE Total'] = dfvol['TOTAL_LOOSE Agency']+dfvol['TOTAL_LOOSE Education']+dfvol['TOTAL_LOOSE Reference']+dfvol['TOTAL_LOOSE Test Prep']+dfvol['TOTAL_LOOSE Trade']
dfvol['TOTAL PALLETS Total']= dfvol['TOTAL_PALLETS Agency']+dfvol['TOTAL_PALLETS Education']+dfvol['TOTAL_PALLETS Reference']+dfvol['TOTAL_PALLETS Test Prep']+dfvol['TOTAL_PALLETS Trade']
dfvol['TOTAL UNITS Total'] = dfvol['TOTAL_UNITS Agency']+dfvol['TOTAL_UNITS Education']+dfvol['TOTAL_UNITS Reference']+dfvol['TOTAL_UNITS Test Prep']+dfvol['TOTAL_UNITS Trade']
dfvol['CARTON_WEIGHT Total'] = dfvol['CARTON_WEIGHT Agency']+dfvol['CARTON_WEIGHT Education']+dfvol['CARTON_WEIGHT Reference']+dfvol['CARTON_WEIGHT Test Prep']+dfvol['CARTON_WEIGHT Trade']

# join vol data to freight data
dffreight = freight[['INVNUMBER','INTDATE','TOTALCHARGE']]
df1 = pd.merge(left=dfvol, right=dffreight, how='left', left_on=['INVOICENO','CJDAT1'], right_on=['INVNUMBER','INTDATE'],copy=False)
df1['TOTALCHARGE'] = df1['TOTALCHARGE'].fillna(0)
df1 = df1.drop(columns=['INVNUMBER','INTDATE'],axis=1)

# Convert dates to dates & add monthly fields
df1['SHIP_MONTH'] = df1['IHAEDT']+19000000
df1['SHIP_MONTH'] = pd.to_datetime(df1['SHIP_MONTH'],format='%Y%m%d')
df1['SHIP_MONTH'] = df1['SHIP_MONTH'].dt.to_period('M')

# Print resulting columns
df1.head()
# Out:
#     CJDAT1   IHINDT   IHAEDT  INVOICENO COLLECT_METHOD CARRIER_CODE  \
# 0        0  1180911  1180911    9477531              Y         UPSN
# 1  1180202  1180202  1180518    6302931              Y         INTN
# 2  1180206  1180206  1180518    6345851              Y         INTN
# 3  1180206  1180206  1180518    6348364              Y         INTN
# 4  1180206  1180206  1180518    6348365              Y         INTN
#
#   PRIORITY_CODE                     SHIP_METHOD             FREIGHT_TYPE  \
# 0            A3  UPS 2-Day Collect - Acct# Req.     Domestic Air Courier
# 1            IX        GP OCEAN FREIGHT COLLECT  Subsidiary Ship Methods
# 2            IX        GP OCEAN FREIGHT COLLECT  Subsidiary Ship Methods
# 3            IX        GP OCEAN FREIGHT COLLECT  Subsidiary Ship Methods
# 4            IX        GP OCEAN FREIGHT COLLECT  Subsidiary Ship Methods
#
#   SHIP_COUNTRY_NAME     ...      CARTON_WEIGHT Reference  \
# 0     United States     ...                          0.0
# 1         Singapore     ...                          0.0
# 2         Singapore     ...                          0.0
# 3         Singapore     ...                          0.0
# 4         Singapore     ...                          0.0
#
#    CARTON_WEIGHT Test Prep  CARTON_WEIGHT Trade  TOTAL CARTONS Total  \
# 0                      0.0                 0.00                    0
# 1                      0.0               336.00                    0
# 2                      0.0               216.00                    0
# 3                    688.0                 0.00                   10
# 4                      0.0              1500.24                    0
#
#    TOTAL LOOSE Total  TOTAL PALLETS Total  TOTAL UNITS Total  \
# 0                  2                    0                  2
# 1                 20                    0                 20
# 2                 10                    0                 10
# 3                  0                    0                 10
# 4                  5                    0                 19
#
#    CARTON_WEIGHT Total  TOTALCHARGE  SHIP_MONTH
# 0                25.60          0.0     2018-09
# 1               336.00          0.0     2018-05
# 2               216.00          0.0     2018-05
# 3               688.00          0.0     2018-05
# 4              1500.24          0.0     2018-05
#
# [5 rows x 53 columns]

# %%
# Additional data wrangling - adding in Region (Continent)
regions = pd.read_csv(wd + 'countries.csv', low_memory=False) 
df2 = pd.merge(left=df1, right=regions, how='left', left_on=['SHIP_COUNTRY_NAME'], right_on=['Country'],copy=False)
df2 = df2.drop(columns=['Country'],axis=1)

# Convert market outlet to categorical
#df2['MARKET_OUTLET'] = str(df2['MARKET_OUTLET'], encoding='ascii', errors='ignore')

# Remove redundant/nonrelevant columns
#df2 = df2.drop(['INVOICENO','SHIP_MONTH','SHIP_COUNTRY_NAME'],axis=1)

# %% [markdown]
# ### Machine Learning Model
#
# #### Preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing as pp

# Scale continuous
scaler = pp.MinMaxScaler()
scaled1 = scaler.fit_transform(df2.iloc[:,10:51])
df2.iloc[:,10:51] = scaled1
scaled2 = scaler.fit_transform(df2.iloc[:,0:3])
df2.iloc[:,0:3] = scaled2

# Generate dummy variables
df2 = pd.DataFrame(pd.get_dummies(df2))

# Test/train split at 80% train, 20% test
X = df2.drop('TOTALCHARGE',axis=1).values
y = df2['TOTALCHARGE'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=24)

# %% [markdown]
# For this dataset, we preprocessed using a min/max scaler for continuous variables as well as one-hot encoding for categorical variables.  Data was split into a training and test set using an 80/20 split, respectively.
#
# #### Basic Linear Regression

# %%
# Fit & predict the model

linreg = linear_model.LinearRegression()
linreg.fit(X_train, y_train)
y_pred = linreg.predict(X_test)
print('R2 =',linreg.score(X_test, y_test),', therefore 30% of the variance in the observed data can be explained by the model.')
# can also use: print(metrics.r2_score(y_test, y_pred))
print('MAE =',metrics.mean_absolute_error(y_test, y_pred))
print('MSE = ',metrics.mean_squared_error(y_test, y_pred))
print('RMSE =',np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 = 0.30688907630382656 , therefore 30% of the variance in the observed data can be explained by the model.
# MAE = 4.6350903386760685
# MSE =  629.9732740156463
# RMSE = 25.099268396023945

# %%
print("Coefficient mean:",np.mean(linreg.coef_))
print("Coefficient median:",np.median(linreg.coef_))
print("Coefficient minimum:",np.min(linreg.coef_))
print("Coefficient maxmimum:",np.max(linreg.coef_))
print("")
print("Model Coefficients:")
cols = df2.drop('TOTALCHARGE',axis=1)
for idx, col_name in enumerate(cols.columns):
    print("The coefficient for {} is {}".format(col_name, linreg.coef_[0][idx]))
# Out:
# Coefficient mean: -1.6225903019810954
# Coefficient median: -1.426133792766509
# Coefficient minimum: -878.1795679223164
# Coefficient maxmimum: 1569.9403827435558
#
# Model Coefficients:
# The coefficient for CJDAT1 is -1.0559740388654515
# The coefficient for IHINDT is 1.429683709949395
# The coefficient for IHAEDT is -323.34348965171415
# The coefficient for INVOICENO is -5.8648508272085564e-09
# The coefficient for MARKET_OUTLET is 6.124462822876769
# The coefficient for BOOK_WEIGHT Agency is 159.45243995337103
# The coefficient for BOOK_WEIGHT Education is 188.50730103458835
# The coefficient for BOOK_WEIGHT Reference is 101.09642594590842
# The coefficient for BOOK_WEIGHT Test Prep is -78.50115046026755
# The coefficient for BOOK_WEIGHT Trade is 286.5998846172291
# The coefficient for TOTAL_LINES Agency is -93.891862184638
# The coefficient for TOTAL_LINES Education is -282.05650686084476
# The coefficient for TOTAL_LINES Reference is 15.91609446592789
# The coefficient for TOTAL_LINES Test Prep is -26.805194914397394
# The coefficient for TOTAL_LINES Trade is -254.0773952707895
# The coefficient for TOTAL_CARTONS Agency is -169.7107338630729
# The coefficient for TOTAL_CARTONS Education is -117.648010236457
# The coefficient for TOTAL_CARTONS Reference is 77.69761479257504
# The coefficient for TOTAL_CARTONS Test Prep is 258.58435297702516
# The coefficient for TOTAL_CARTONS Trade is -863.8076519091346
# The coefficient for TOTAL_LOOSE Agency is -175.08349100087773
# The coefficient for TOTAL_LOOSE Education is 62.575728013481566
# The coefficient for TOTAL_LOOSE Reference is 35.13273681715844
# The coefficient for TOTAL_LOOSE Test Prep is 473.25274750075846
# The coefficient for TOTAL_LOOSE Trade is -59.42463644375694
# The coefficient for TOTAL_PALLETS Agency is -7.989342520886566e-11
# The coefficient for TOTAL_PALLETS Education is -256.768454327766
# The coefficient for TOTAL_PALLETS Reference is 246.65680224333812
# The coefficient for TOTAL_PALLETS Test Prep is -277.4745510739276
# The coefficient for TOTAL_PALLETS Trade is -619.7857465285202
# The coefficient for TOTAL_UNITS Agency is 281.41909095154205
# The coefficient for TOTAL_UNITS Education is 261.7521787310908
# The coefficient for TOTAL_UNITS Reference is -186.62463699525946
# The coefficient for TOTAL_UNITS Test Prep is 788.6404159261887
# The coefficient for TOTAL_UNITS Trade is 1441.5616653964241
# The coefficient for CARTON_WEIGHT Agency is -26.04883982903999
# The coefficient for CARTON_WEIGHT Education is 510.4891577851302
# The coefficient for CARTON_WEIGHT Reference is -211.33518494243324
# The coefficient for CARTON_WEIGHT Test Prep is -726.8031286160501
# The coefficient for CARTON_WEIGHT Trade is -583.2145567559475
# The coefficient for TOTAL CARTONS Total is -878.1795679223164
# The coefficient for TOTAL LOOSE Total is -35.91082545402623
# The coefficient for TOTAL PALLETS Total is -637.5647356716768
# The coefficient for TOTAL UNITS Total is 1569.9403827435558
# The coefficient for CARTON_WEIGHT Total is -576.1814934685107
# The coefficient for COLLECT_METHOD_N is 49.68319157567103
# The coefficient for COLLECT_METHOD_Y is -49.68319159273992
# The coefficient for CARRIER_CODE_9CLT is 2.6713890191212264
# The coefficient for CARRIER_CODE_A&BC is 10.586789054188575
# The coefficient for CARRIER_CODE_AACT is -5.083467587227229
# The coefficient for CARRIER_CODE_ABFS is 2.3676709090149672
# The coefficient for CARRIER_CODE_AWBC is 4.002966003122051
# The coefficient for CARRIER_CODE_BNPU is 3.833894016680418
# The coefficient for CARRIER_CODE_BRPR is 5.03221089019794
# The coefficient for CARRIER_CODE_BTPU is 6.283864938851318
# The coefficient for CARRIER_CODE_CANF is -1.8612169068437192
# The coefficient for CARRIER_CODE_CANP is -35.85158354336468
# The coefficient for CARRIER_CODE_CANS is -49.04667821734329
# The coefficient for CARRIER_CODE_CBNK is 4.126720212131007
# The coefficient for CARRIER_CODE_CEVA is 10.938446806527029
# The coefficient for CARRIER_CODE_CFFO is 4.499217796430982
# The coefficient for CARRIER_CODE_CGCC is -4.047247448741569
# The coefficient for CARRIER_CODE_CGPC is -35.69993952509001
# The coefficient for CARRIER_CODE_CGPP is -67.57238550887509
# The coefficient for CARRIER_CODE_CGTD is -6.441963963666543
# The coefficient for CARRIER_CODE_CMKY is 1.738630374045032
# The coefficient for CARRIER_CODE_COYO is -5.906575897550355
# The coefficient for CARRIER_CODE_CPU  is 11.293461507255325
# The coefficient for CARRIER_CODE_CTII is -7.107412666405894
# The coefficient for CARRIER_CODE_CWCE is -4.913022886529932
# The coefficient for CARRIER_CODE_DAFG is -4.025865322087162
# The coefficient for CARRIER_CODE_DAYR is 3.200582768086036
# The coefficient for CARRIER_CODE_DHLC is 4.5464622530057515
# The coefficient for CARRIER_CODE_ECHO is 4.544896756758702
# The coefficient for CARRIER_CODE_EWCF is -74.58628350797841
# The coefficient for CARRIER_CODE_EXLA is -4.592000620699848
# The coefficient for CARRIER_CODE_FDCC is 15.52703927484351
# The coefficient for CARRIER_CODE_FDEC is 19.056167785507697
# The coefficient for CARRIER_CODE_FDFF is 7.225400100494612
# The coefficient for CARRIER_CODE_FEDX is 15.870206202617604
# The coefficient for CARRIER_CODE_FXFE is 97.07675854368689
# The coefficient for CARRIER_CODE_FXNL is 149.866964291741
# The coefficient for CARRIER_CODE_GTS  is -3.0675267553131684
# The coefficient for CARRIER_CODE_GTW  is -64.94100418601414
# The coefficient for CARRIER_CODE_HJBT is 0.9970178759401281
# The coefficient for CARRIER_CODE_IGPU is 5.9564195505033295
# The coefficient for CARRIER_CODE_INTN is -7.133560317719834
# The coefficient for CARRIER_CODE_LCSL is 12.958224076097192
# The coefficient for CARRIER_CODE_MAIS is 2.4409232964166963
# The coefficient for CARRIER_CODE_NATX is 13.410494190885172
# The coefficient for CARRIER_CODE_NEMF is -5.001326387199367
# The coefficient for CARRIER_CODE_ODFL is -2.9882025904642227
# The coefficient for CARRIER_CODE_PITD is -5.000642660327774
# The coefficient for CARRIER_CODE_PURL is 19.855078913015863
# The coefficient for CARRIER_CODE_QXTI is 1.8913888813654336
# The coefficient for CARRIER_CODE_RBTW is -11.01141623010546
# The coefficient for CARRIER_CODE_RDWY is -7.441567977324027
# The coefficient for CARRIER_CODE_REIM is 1.623156905294907
# The coefficient for CARRIER_CODE_RLTJ is -4.008327811636745
# The coefficient for CARRIER_CODE_RRUN is -2.0990450651808517
# The coefficient for CARRIER_CODE_RTAL is 5.23886219137971
# The coefficient for CARRIER_CODE_SAIA is -4.8517598667249375
# The coefficient for CARRIER_CODE_SDCR is 4.232418853550999
# The coefficient for CARRIER_CODE_TPQL is -5.852960399730529
# The coefficient for CARRIER_CODE_UPGF is 8.452752207503998
# The coefficient for CARRIER_CODE_UPSC is 19.88478645424232
# The coefficient for CARRIER_CODE_UPSN is 4.458088735741285
# The coefficient for CARRIER_CODE_USPS is -48.3474331905999
# The coefficient for CARRIER_CODE_USXI is -5.966143031890368
# The coefficient for CARRIER_CODE_VITY is 3.794606942800552
# The coefficient for CARRIER_CODE_XMAR is -8.929784772088269
# The coefficient for CARRIER_CODE_YKPU is 3.8923869851410604
# The coefficient for PRIORITY_CODE_A1 is 9.221749394380929
# The coefficient for PRIORITY_CODE_A3 is -15.49739635618661
# The coefficient for PRIORITY_CODE_A4 is -12.779981958452291
# The coefficient for PRIORITY_CODE_G1 is -7.986738777345189
# The coefficient for PRIORITY_CODE_G2 is -6.016889745247771
# The coefficient for PRIORITY_CODE_GS is -4.478754530498037
# The coefficient for PRIORITY_CODE_IS is -8.770032076247066
# The coefficient for PRIORITY_CODE_IX is 36.18267081173943
# The coefficient for PRIORITY_CODE_S  is 10.125373441120487
# The coefficient for SHIP_METHOD_2 DAY UPS FREIGHT COLL is 18.17120954463343
# The coefficient for SHIP_METHOD_A&B Courier from GTW is 12.603793184080539
# The coefficient for SHIP_METHOD_A&B LTL Services from GTW is -2.0170041305894517
# The coefficient for SHIP_METHOD_AAA COOPER COLLECT is -5.083467587793697
# The coefficient for SHIP_METHOD_ABF Coll 3rd Party Billing is -13.176439813983386
# The coefficient for SHIP_METHOD_ABF Freight Systems Collect is 15.544110721173586
# The coefficient for SHIP_METHOD_AVERITT EXPRESS is -1.4131957952751126
# The coefficient for SHIP_METHOD_Air Mail International is 3.6126877641682844
# The coefficient for SHIP_METHOD_American Wholesale Book is 4.0029660027133485
# The coefficient for SHIP_METHOD_B&N Customer Manifest is 3.8338941131979425
# The coefficient for SHIP_METHOD_BAKER & TAYLOR - COMMERCE,GA is 1.487704209299019
# The coefficient for SHIP_METHOD_BAKER & TAYLOR - MOMENCE, IL is 1.6871174240923628
# The coefficient for SHIP_METHOD_BAKER & TAYLOR - RENO, NV is 1.7747189022138459
# The coefficient for SHIP_METHOD_BAKER & TAYLOR-BRIDGEWATER,NJ is 1.3343243633361992
# The coefficient for SHIP_METHOD_BR PRINTERS - PICKUP is 5.032210890270688
# The coefficient for SHIP_METHOD_C.H. Robinson - Collect is -11.011416230235534
# The coefficient for SHIP_METHOD_CANPAR GROUND is -35.85158372475395
# The coefficient for SHIP_METHOD_CANPAR OVERNIGHT is -23.53746540283238
# The coefficient for SHIP_METHOD_CANPAR Select is -25.5092128132284
# The coefficient for SHIP_METHOD_CCX - Collect is -2.2142972805456425
# The coefficient for SHIP_METHOD_CENTRAL TRANSPORT 3RD PARTY is -7.10741266637839
# The coefficient for SHIP_METHOD_CEVA/EGL/FASTAIR 2 DAY COLLECT is 10.938446806749756
# The coefficient for SHIP_METHOD_CORMAKYE TRANSPORT is 1.7386303740640088
# The coefficient for SHIP_METHOD_COYOTE TRUCKING is -5.906575897077345
# The coefficient for SHIP_METHOD_Cabano Kingsway Collect is 4.126720212014201
# The coefficient for SHIP_METHOD_Canadian Freightways Collect is -1.861216906642326
# The coefficient for SHIP_METHOD_Cengage Generic 3rd Party is -6.4419639637534285
# The coefficient for SHIP_METHOD_Cengage Generic Pre Paid is -67.57238550886017
# The coefficient for SHIP_METHOD_Cengage Generic Pre Paid Add is -35.69993952475972
# The coefficient for SHIP_METHOD_Cengage Generic Shipmethod Col is -4.047247445084887
# The coefficient for SHIP_METHOD_Clarke Transport Collect is 2.6713890187984752
# The coefficient for SHIP_METHOD_Consolidated Fastfrate Collect is 4.499217796759834
# The coefficient for SHIP_METHOD_Conway Freight 3rd Party is -2.698725603825014
# The coefficient for SHIP_METHOD_Customer Own Pickup is -14.079039986244307
# The coefficient for SHIP_METHOD_Customer Pick Up Int'l Air Col is 7.091434960716347
# The coefficient for SHIP_METHOD_Customer Pick Up Two Day Air is 18.28106653544163
# The coefficient for SHIP_METHOD_DAYTON FREIGHT COLLECT is -4.02586532121753
# The coefficient for SHIP_METHOD_DHL Int'l Collect is 4.546462253148364
# The coefficient for SHIP_METHOD_Day & Ross 3rd Party from GTW is 3.200582767542833
# The coefficient for SHIP_METHOD_ECHO GLOBAL LOGISTICS is 4.544896756656644
# The coefficient for SHIP_METHOD_ESTES THIRD PARTY is -1.2503377227067878
# The coefficient for SHIP_METHOD_Emery Intl PrePaid is -74.58628350799707
# The coefficient for SHIP_METHOD_Estes Express Collect is -3.341662898058753
# The coefficient for SHIP_METHOD_ExMark Transportation is -8.929784772086267
# The coefficient for SHIP_METHOD_FDX 1-Day Priority  10:30 PPD is 5.432800490242433
# The coefficient for SHIP_METHOD_FDX 2-Day Standard - 4:30 pm is -60.42292555727702
# The coefficient for SHIP_METHOD_FDX-1 Priority Collect - 10:30 is 0.09119880367276201
# The coefficient for SHIP_METHOD_FDX-2 Standard Collect - 4:30 is 25.26690477937734
# The coefficient for SHIP_METHOD_FED EX FREIGHT COLLECT is -106.82948911027287
# The coefficient for SHIP_METHOD_FEDEX 2DAY COLLECT FROM GTW is 5.993202067373014
# The coefficient for SHIP_METHOD_FEDEX FREIGHT ECONOMY 3RD PTY is -104.19530787907834
# The coefficient for SHIP_METHOD_FEDEX FREIGHT ECONOMY COLLECT is -157.12890066275477
# The coefficient for SHIP_METHOD_FEDEX FREIGHT PPD is 308.10155553381185
# The coefficient for SHIP_METHOD_FEDEX INT'L ECONOMY COLLECT is -8.58710684362777
# The coefficient for SHIP_METHOD_FEDEX National Pre-Paid is 306.9958649537538
# The coefficient for SHIP_METHOD_FEDEX OVERNIGH ECON CANADA is 6.9589184917284665
# The coefficient for SHIP_METHOD_FedEx 1-Day Std. 3rd Party is -0.46049875479821356
# The coefficient for SHIP_METHOD_FedEx 2-Day Third Party Bill is 24.194026768765834
# The coefficient for SHIP_METHOD_FedEx Int'l Priority Collect is 1.4946613848360584
# The coefficient for SHIP_METHOD_FedEx Int'l Priority Prepaid is 0.6072101665665635
# The coefficient for SHIP_METHOD_FedEx International Economy PP is 15.870206202779984
# The coefficient for SHIP_METHOD_FedEx Next Day 3:00 PM Collect is -1.0631105369025704
# The coefficient for SHIP_METHOD_Federal Express Saver Collect is 20.672239487942875
# The coefficient for SHIP_METHOD_Fedex Ground 3rd Party is 19.62698044667531
# The coefficient for SHIP_METHOD_Fedex Ground Bill Recipient is 58.982099351288525
# The coefficient for SHIP_METHOD_Fedex Ground Collect from GTW is 6.104047223901154
# The coefficient for SHIP_METHOD_Fedex Ground Pre-Paid is -63.08204037949915
# The coefficient for SHIP_METHOD_GP AIR FREIGHT COLLECT is -2.3906253275880474
# The coefficient for SHIP_METHOD_GP OCEAN FREIGHT COLLECT is -3.329739204574933
# The coefficient for SHIP_METHOD_GTS Third Party is -3.0675267557426733
# The coefficient for SHIP_METHOD_GTW Express One Day PPD is -13.230409311762028
# The coefficient for SHIP_METHOD_GTW Express Two Day PPD is -16.853891905339847
# The coefficient for SHIP_METHOD_GTW LTL Prepaid is -25.950938618314876
# The coefficient for SHIP_METHOD_GTW Small Package Ground PPD is -8.905764384516411
# The coefficient for SHIP_METHOD_Ingram Books Customer Pickup is 1.1600103004972884
# The coefficient for SHIP_METHOD_Ingram Consol. FT. WAYNE, IN is 0.7798076981289281
# The coefficient for SHIP_METHOD_Ingram Consol. LAVERGNE TN is 1.4263953953448796
# The coefficient for SHIP_METHOD_Ingram Consol. PETERSBRUG is 1.8673969217463342
# The coefficient for SHIP_METHOD_Ingram Consol. ROSEBURG is 0.7228092301948243
# The coefficient for SHIP_METHOD_JB HUNT COLLECT is 0.9970178802732382
# The coefficient for SHIP_METHOD_LOOMIS AIR COLLECT is 14.260242123153473
# The coefficient for SHIP_METHOD_LOOMIS GRD COLLECT is -1.3020180470954112
# The coefficient for SHIP_METHOD_MI USPS Parcel Consol. is -18.450460568979686
# The coefficient for SHIP_METHOD_Nationex Ground Collect is 13.41049419080806
# The coefficient for SHIP_METHOD_New England Motor Frt. Collect is -5.001326387620277
# The coefficient for SHIP_METHOD_Old Dominion Freight Collect is -2.9882025904517304
# The coefficient for SHIP_METHOD_PUROLATOR 2 DAY AIR COLLECT is 5.192744027230446
# The coefficient for SHIP_METHOD_PUROLATOR GROUND COLLECT is 7.100359558311963
# The coefficient for SHIP_METHOD_Pitt Ohio 3rd Party is -2.33796461929896
# The coefficient for SHIP_METHOD_Pitt Ohio Collect is -2.66267805267763
# The coefficient for SHIP_METHOD_Priority Mail (USA) is -19.483829908322058
# The coefficient for SHIP_METHOD_Purolator AIR Collect is 7.561975324927026
# The coefficient for SHIP_METHOD_QUIKTRAX INTERMODAL COLLECT is 1.8913888811844286
# The coefficient for SHIP_METHOD_R & L Carriers Collect is -4.008327807221192
# The coefficient for SHIP_METHOD_REIMER Collect is 1.623156905250089
# The coefficient for SHIP_METHOD_REIMER TRANSPORT (Maisliner) is 2.440923296440751
# The coefficient for SHIP_METHOD_ROADRUNNER 3rd party is -2.099045065261722
# The coefficient for SHIP_METHOD_ROSEDALE GROUP is 5.238862191272673
# The coefficient for SHIP_METHOD_SAIA is -4.851759866864389
# The coefficient for SHIP_METHOD_SAMEDAY RIGHT-O-WAY COLLECT is 4.232418853836135
# The coefficient for SHIP_METHOD_TRANSPLACE COLLECT is -5.852960399409907
# The coefficient for SHIP_METHOD_UPS 1-Day Air is -64.29070377103592
# The coefficient for SHIP_METHOD_UPS 1-Day Collect - Acct# Req. is -0.7975883227118019
# The coefficient for SHIP_METHOD_UPS 2 DAY COLLECT FROM GTW is 14.221822072541402
# The coefficient for SHIP_METHOD_UPS 2-Day Air is -48.35451110277347
# The coefficient for SHIP_METHOD_UPS 2-Day Collect - Acct# Req. is 26.850662758073028
# The coefficient for SHIP_METHOD_UPS 2-Day Puerto Rico Collect is -24.683280086420815
# The coefficient for SHIP_METHOD_UPS 3-Day Air is -57.09880188714499
# The coefficient for SHIP_METHOD_UPS 3-Day Collect Acct.# Req. is 23.64658044021065
# The coefficient for SHIP_METHOD_UPS Canada Ground is -45.774581727721674
# The coefficient for SHIP_METHOD_UPS Canada Ground Collect is 6.620041941489641
# The coefficient for SHIP_METHOD_UPS Canada Int'l Saver Prepaid is 23.019314250433425
# The coefficient for SHIP_METHOD_UPS FREIGHT COLLECT is -22.61363250197659
# The coefficient for SHIP_METHOD_UPS FREIGHT THIRD PARTY is -17.056865438182648
# The coefficient for SHIP_METHOD_UPS Freight Pre-Paid is 29.952040594682863
# The coefficient for SHIP_METHOD_UPS Ground is -58.67719431240326
# The coefficient for SHIP_METHOD_UPS Ground Collect Acct# Req. is 29.78626249605722
# The coefficient for SHIP_METHOD_UPS Ground Collect Canada is 5.662964383565162
# The coefficient for SHIP_METHOD_UPS Ground Collect Puerto Rico is 49.19910218744328
# The coefficient for SHIP_METHOD_UPS Ground Puerto Rico is -15.807240287409465
# The coefficient for SHIP_METHOD_UPS Int'l Expedited Collect is 15.696523619780162
# The coefficient for SHIP_METHOD_UPS Int'l Express Collect is -4.1340044415341195
# The coefficient for SHIP_METHOD_UPS Next Day Sat. Delivery is 70.3096514197509
# The coefficient for SHIP_METHOD_UPS Puerto Rico 1-Day is 6.916701472874487
# The coefficient for SHIP_METHOD_UPS Puerto Rico 2-Day is 72.03115383405354
# The coefficient for SHIP_METHOD_US EXPRESS COLLECT is -5.966143034751704
# The coefficient for SHIP_METHOD_USPS FIRST CLASS is -14.025830482242519
# The coefficient for SHIP_METHOD_VITRAN TRANSWEST'N EXP COLLECT is 3.7946069454947553
# The coefficient for SHIP_METHOD_YRC 3rd Party is 0.8418624338287
# The coefficient for SHIP_METHOD_YRC COLLECT is -8.283430409569782
# The coefficient for SHIP_METHOD_Yankee Book Consol. is 3.892386985659842
# The coefficient for FREIGHT_TYPE_Consolidations is 4.002966002715651
# The coefficient for FREIGHT_TYPE_Customer Pick Up is 11.429440784517823
# The coefficient for FREIGHT_TYPE_Domestic Air Courier is 17.03773671370037
# The coefficient for FREIGHT_TYPE_Domestic Air Freight is 18.171209544655813
# The coefficient for FREIGHT_TYPE_Domestic Ground Freight is 26.57115554058035
# The coefficient for FREIGHT_TYPE_Domestic Ground Small Package is -12.448321716499805
# The coefficient for FREIGHT_TYPE_GTW Air Courier is -8.358753832480055
# The coefficient for FREIGHT_TYPE_GTW Ground Freight is 4.326719571352057
# The coefficient for FREIGHT_TYPE_GTW Ground Small Package is -12.479482435327952
# The coefficient for FREIGHT_TYPE_Int'l Air Courier is -8.409975793343973
# The coefficient for FREIGHT_TYPE_Int'l Surface is -39.15453978571236
# The coefficient for FREIGHT_TYPE_Internal Use Only is 5.032210890273488
# The coefficient for FREIGHT_TYPE_Subsidiary Ship Methods is -5.720364553146654
# The coefficient for SHIP_COUNTRY_NAME_Afghanistan is 16.7640806366737
# The coefficient for SHIP_COUNTRY_NAME_Algeria is 1.826216044429572
# The coefficient for SHIP_COUNTRY_NAME_Antigua & Barbuda is 26.987487056381152
# The coefficient for SHIP_COUNTRY_NAME_Argentina is -94.50693535028486
# The coefficient for SHIP_COUNTRY_NAME_Aruba is -7.421660589820608
# The coefficient for SHIP_COUNTRY_NAME_Australia is 4.3480854910185185
# The coefficient for SHIP_COUNTRY_NAME_Austria is -19.34880206895924
# The coefficient for SHIP_COUNTRY_NAME_Azerbaijan is 3.0852784603620993
# The coefficient for SHIP_COUNTRY_NAME_Bahamas is -32.05589699974433
# The coefficient for SHIP_COUNTRY_NAME_Bahrain is -29.312558819473004
# The coefficient for SHIP_COUNTRY_NAME_Bangladesh is 73.42468141172301
# The coefficient for SHIP_COUNTRY_NAME_Barbados is 7.198153050702599
# The coefficient for SHIP_COUNTRY_NAME_Belarus is -6.632365327082223
# The coefficient for SHIP_COUNTRY_NAME_Belgium is 11.39732543106203
# The coefficient for SHIP_COUNTRY_NAME_Belize is 26.630441473121536
# The coefficient for SHIP_COUNTRY_NAME_Bermuda is -2.9441077202107877
# The coefficient for SHIP_COUNTRY_NAME_Bolivia is -92.38211915627592
# The coefficient for SHIP_COUNTRY_NAME_Botswana is 11.786234355601522
# The coefficient for SHIP_COUNTRY_NAME_Brazil is -78.87670344516461
# The coefficient for SHIP_COUNTRY_NAME_Brunei is -16.950860067942166
# The coefficient for SHIP_COUNTRY_NAME_Bulgaria is -2.309683521024359
# The coefficient for SHIP_COUNTRY_NAME_Cambodia is -0.8694420225197269
# The coefficient for SHIP_COUNTRY_NAME_Canada is 10.310586740834708
# The coefficient for SHIP_COUNTRY_NAME_Cayman Islands is 86.4649795896826
# The coefficient for SHIP_COUNTRY_NAME_Chile is -54.225760060972085
# The coefficient for SHIP_COUNTRY_NAME_China is 2.280041992782079
# The coefficient for SHIP_COUNTRY_NAME_Colombia is -49.927957611651514
# The coefficient for SHIP_COUNTRY_NAME_Costa Rica is 107.87884012420896
# The coefficient for SHIP_COUNTRY_NAME_Croatia is 46.607829712913556
# The coefficient for SHIP_COUNTRY_NAME_Curacao is -24.321188962496105
# The coefficient for SHIP_COUNTRY_NAME_Cyprus is -27.854220630289074
# The coefficient for SHIP_COUNTRY_NAME_Czech Republic is -7.894757802128535
# The coefficient for SHIP_COUNTRY_NAME_Denmark is 6.759775873813802
# The coefficient for SHIP_COUNTRY_NAME_Dominican Republic is 19.7355832824169
# The coefficient for SHIP_COUNTRY_NAME_Ecuador is 31.08861905534717
# The coefficient for SHIP_COUNTRY_NAME_Egypt is -35.11443508485189
# The coefficient for SHIP_COUNTRY_NAME_El Salvador is 5.723156084074247
# The coefficient for SHIP_COUNTRY_NAME_Estonia is -1.3562840042431101
# The coefficient for SHIP_COUNTRY_NAME_Finland is -27.7823899705868
# The coefficient for SHIP_COUNTRY_NAME_Foreign Purchase  (Usa) is -1.8313265065172348
# The coefficient for SHIP_COUNTRY_NAME_France is -15.102210797925528
# The coefficient for SHIP_COUNTRY_NAME_Georgia is -0.2517704898119156
# The coefficient for SHIP_COUNTRY_NAME_Germany is -0.659800042336028
# The coefficient for SHIP_COUNTRY_NAME_Ghana is 7.215313387964335
# The coefficient for SHIP_COUNTRY_NAME_Greece is -23.883256538648926
# The coefficient for SHIP_COUNTRY_NAME_Greenland is -6.8549621541536325
# The coefficient for SHIP_COUNTRY_NAME_Grenada is -23.294073981443606
# The coefficient for SHIP_COUNTRY_NAME_Guadeloupe is -2.8657504786886214
# The coefficient for SHIP_COUNTRY_NAME_Guam is 32.61588197851978
# The coefficient for SHIP_COUNTRY_NAME_Guatemala is 395.01521574446593
# The coefficient for SHIP_COUNTRY_NAME_Guernsey is -46.74207906142324
# The coefficient for SHIP_COUNTRY_NAME_Honduras is -16.710676295449968
# The coefficient for SHIP_COUNTRY_NAME_Hong Kong is -2.689546590453559
# The coefficient for SHIP_COUNTRY_NAME_Hungary is -3.7115610695432366
# The coefficient for SHIP_COUNTRY_NAME_Iceland is 333.03366089769054
# The coefficient for SHIP_COUNTRY_NAME_India is 7.961591668691788
# The coefficient for SHIP_COUNTRY_NAME_Indonesia is 38.00104246424131
# The coefficient for SHIP_COUNTRY_NAME_Iran is 13.135248826037333
# The coefficient for SHIP_COUNTRY_NAME_Iraq is 0.0
# The coefficient for SHIP_COUNTRY_NAME_Ireland is -24.91471874820754
# The coefficient for SHIP_COUNTRY_NAME_Israel is 3.5240852191347307
# The coefficient for SHIP_COUNTRY_NAME_Italy is -17.722927791402316
# The coefficient for SHIP_COUNTRY_NAME_Jamaica is -5.522850735718745
# The coefficient for SHIP_COUNTRY_NAME_Japan is -1.2378796612529808
# The coefficient for SHIP_COUNTRY_NAME_Jersey is 105.33246360658616
# The coefficient for SHIP_COUNTRY_NAME_Jordan is 14.896156612468518
# The coefficient for SHIP_COUNTRY_NAME_Kazakhstan is -4.74799999239426
# The coefficient for SHIP_COUNTRY_NAME_Kenya is -3.6401155267679286
# The coefficient for SHIP_COUNTRY_NAME_Kuwait is 50.24784519871513
# The coefficient for SHIP_COUNTRY_NAME_Latvia is -19.150160210149092
# The coefficient for SHIP_COUNTRY_NAME_Lebanon is -4.816433873682805
# The coefficient for SHIP_COUNTRY_NAME_Liberia is 11.723269714842479
# The coefficient for SHIP_COUNTRY_NAME_Libya is -1.5241756617275184
# The coefficient for SHIP_COUNTRY_NAME_Liechtenstein is -2.1971863558067564
# The coefficient for SHIP_COUNTRY_NAME_Lithuania is -3.3710469438905357
# The coefficient for SHIP_COUNTRY_NAME_Luxembourg is -21.95328623728608
# The coefficient for SHIP_COUNTRY_NAME_Macedonia is -4.622366682494252
# The coefficient for SHIP_COUNTRY_NAME_Malaysia is -80.65248287236761
# The coefficient for SHIP_COUNTRY_NAME_Malta is -35.418787843050566
# The coefficient for SHIP_COUNTRY_NAME_Mauritius is -3.412070962998136
# The coefficient for SHIP_COUNTRY_NAME_Mexico is -97.10867684071223
# The coefficient for SHIP_COUNTRY_NAME_Monaco is -26.86855601307252
# The coefficient for SHIP_COUNTRY_NAME_Mongolia is 8.586193241521936
# The coefficient for SHIP_COUNTRY_NAME_Morocco is 17.641034665719886
# The coefficient for SHIP_COUNTRY_NAME_Mozambique is 0.0
# The coefficient for SHIP_COUNTRY_NAME_Myanmar is -83.84565519755185
# The coefficient for SHIP_COUNTRY_NAME_Namibia is -123.7857958541969
# The coefficient for SHIP_COUNTRY_NAME_Netherlands is -25.135837337371484
# The coefficient for SHIP_COUNTRY_NAME_New Zealand is -30.366938291365653
# The coefficient for SHIP_COUNTRY_NAME_Nicaragua is 44.71940897933817
# The coefficient for SHIP_COUNTRY_NAME_Nigeria is -16.97771695627811
# The coefficient for SHIP_COUNTRY_NAME_Northern Mariana Islands is 35.5831154161584
# The coefficient for SHIP_COUNTRY_NAME_Norway is -9.60064412221827
# The coefficient for SHIP_COUNTRY_NAME_Oman is -21.296784601038684
# The coefficient for SHIP_COUNTRY_NAME_Pakistan is -23.70874604165128
# The coefficient for SHIP_COUNTRY_NAME_Panama is 131.26232176804282
# The coefficient for SHIP_COUNTRY_NAME_Peru is 33.626410269334684
# The coefficient for SHIP_COUNTRY_NAME_Philippines is -12.57865079623317
# The coefficient for SHIP_COUNTRY_NAME_Poland is -1.4497184400327412
# The coefficient for SHIP_COUNTRY_NAME_Portugal is -5.8596275213668045
# The coefficient for SHIP_COUNTRY_NAME_Puerto Rico is 26.14253874628469
# The coefficient for SHIP_COUNTRY_NAME_Qatar is 7.18033259379317
# The coefficient for SHIP_COUNTRY_NAME_Romania is 3.1875180989664407
# The coefficient for SHIP_COUNTRY_NAME_Russia is -0.3030796798535671
# The coefficient for SHIP_COUNTRY_NAME_Saint Kitts And Nevis is -17.349328108415396
# The coefficient for SHIP_COUNTRY_NAME_Saint Lucia is -10.042009278857018
# The coefficient for SHIP_COUNTRY_NAME_Saipan is 21.361236078179605
# The coefficient for SHIP_COUNTRY_NAME_Saudi Arabia is -21.238236415191363
# The coefficient for SHIP_COUNTRY_NAME_Senegal is 8.348744208146067
# The coefficient for SHIP_COUNTRY_NAME_Serbia is -52.2724124018165
# The coefficient for SHIP_COUNTRY_NAME_Sierra Leone is -4.304493551192534
# The coefficient for SHIP_COUNTRY_NAME_Singapore is 9.945340198089058
# The coefficient for SHIP_COUNTRY_NAME_Slovak Republic is -0.9755371879344567
# The coefficient for SHIP_COUNTRY_NAME_Slovenia is -2.88544030002884
# The coefficient for SHIP_COUNTRY_NAME_South Africa is 1.8451138388089519
# The coefficient for SHIP_COUNTRY_NAME_South Korea is -0.6366837764470017
# The coefficient for SHIP_COUNTRY_NAME_Spain is -10.111899478898335
# The coefficient for SHIP_COUNTRY_NAME_Sri Lanka is -6.29865882878952
# The coefficient for SHIP_COUNTRY_NAME_Swaziland is 10.60272865548601
# The coefficient for SHIP_COUNTRY_NAME_Sweden is -14.4672492367236
# The coefficient for SHIP_COUNTRY_NAME_Switzerland is -7.724381194955629
# The coefficient for SHIP_COUNTRY_NAME_Taiwan is -4.756604204010962
# The coefficient for SHIP_COUNTRY_NAME_Tanzania is 100.72878378432512
# The coefficient for SHIP_COUNTRY_NAME_Thailand is -16.327688322300318
# The coefficient for SHIP_COUNTRY_NAME_Trinidad And Tobago is -12.063207169673612
# The coefficient for SHIP_COUNTRY_NAME_Turkey is -31.249636284733278
# The coefficient for SHIP_COUNTRY_NAME_Uganda is 13.429046470649697
# The coefficient for SHIP_COUNTRY_NAME_Ukraine is 4.621279139209257
# The coefficient for SHIP_COUNTRY_NAME_United Arab Emirates is -24.1849364579147
# The coefficient for SHIP_COUNTRY_NAME_United Kingdom is 2.509689834912111
# The coefficient for SHIP_COUNTRY_NAME_United States is 0.39225517946660204
# The coefficient for SHIP_COUNTRY_NAME_Unknown is -29.74535463845435
# The coefficient for SHIP_COUNTRY_NAME_Uruguay is -93.06313727877912
# The coefficient for SHIP_COUNTRY_NAME_Us Minor Outlying Islands is -67.12255768661463
# The coefficient for SHIP_COUNTRY_NAME_Venezuela is -100.39214912504087
# The coefficient for SHIP_COUNTRY_NAME_Vietnam is 25.03386583554611
# The coefficient for SHIP_COUNTRY_NAME_Virgin Islands (Us) is -17.981526377826658
# The coefficient for SHIP_COUNTRY_NAME_Zambia is -4.076939647439088
# The coefficient for SHIP_COUNTRY_NAME_Zimbabwe is 0.0
# The coefficient for SHIP_MONTH_2018-05 is -113.5549835973403
# The coefficient for SHIP_MONTH_2018-06 is -109.1426567241374
# The coefficient for SHIP_MONTH_2018-07 is -105.419142187309
# The coefficient for SHIP_MONTH_2018-08 is -102.75591104838473
# The coefficient for SHIP_MONTH_2018-09 is -99.73916827593511
# The coefficient for SHIP_MONTH_2018-10 is -96.44674950562033
# The coefficient for SHIP_MONTH_2018-11 is -94.02051608603898
# The coefficient for SHIP_MONTH_2018-12 is -91.04733633341613
# The coefficient for SHIP_MONTH_2019-01 is 198.5699728617973
# The coefficient for SHIP_MONTH_2019-02 is 201.65497308777194
# The coefficient for SHIP_MONTH_2019-03 is 204.5578792773886
# The coefficient for SHIP_MONTH_2019-04 is 207.34363878399128
# The coefficient for REGION_Africa is -4.277187160789805
# The coefficient for REGION_Asia is -8.079115013323253
# The coefficient for REGION_Australia / Pacific is 6.597029243625389
# The coefficient for REGION_Canada is 10.310586740793866
# The coefficient for REGION_Caribbean is -26.959224406664827
# The coefficient for REGION_Central & South America is 72.11985685040696
# The coefficient for REGION_Europe is -1.9241830535260163
# The coefficient for REGION_Middle East is -18.80994712020895
# The coefficient for REGION_North America is -1.4390717902579055
# The coefficient for REGION_Russia is -0.3030796798680458
# The coefficient for REGION_United Kingdom is 2.509689953298748
# The coefficient for REGION_Unknown is -29.74535463844716

# %% [markdown]
# Given several hundred dummy variables, we can take a look ourselves at some of the coefficients for our basic categories to determine which variables might be more important to the model.  There are a lot of insights to this first round of regression training.
#
# Our mean correlation coefficient is -1.622, whereas our median correlation coefficient is -1.42, indicating that there are a lot of extremely negative coefficients skewing our mean.  In terms of the data, this means that there are some outlier coefficients that have a negative correlation, meaning that as these variables go up, our freight cost goes down quite a bit (or, in the case of dummy variables, freight cost is much lower for the dummy variable classification than for other categorical classifications).  Given the data we're working with, this makes sense--our volume data includes a large number of shipments that aren't associated with any freight cost at all, so we can expect a lot of those cost-free shipments to have negative coefficients.
#
# In terms of specifics, the following variable groups appear to have significant coefficients:
# * Total cartons - coefficients ~ -722 for the total, and ~721-723 for each individual business
# * Carton weight - coefficients ~ 173,810 for the total, and -173,810 for each individual business
# * Collect method Y/N - coefficient for Y at 49, coefficient for N at -49
# * Carrier code - coefficients vary
#     + We can see that certain carrier codes are significant, such as CANP & CANS (Canpar/Canadian shipments) at coefficients of -35 and -48, respectively
#     + FEDX, FXFE, FXNL with coefficients of 13, 97, and 149 respectively - these should be significant as I believe they indicate different types of FEDEX carriers
#     + Other significant carrier codes appear to be UPSC, USPS, CGPC, CGPP
# * Priority code - coefficients between -11 and 37
# * Freight type, ship method
# * Certain ship country names
#     + This was a strange one.  Iceland appears to be the highest, at a coefficient of 330, and Namibia appears to be the lowest, at a coefficient of -129.
# * Month of shipment - extremely significant correlations at ~ -100 or ~ +200
#
# This ends up being quite a bit too many coefficients to reasonably interpret by eyeballing them, so we may want to consider some more in-depth regression models that assist with variable selection and add regularization to the mix.

# %% [markdown]
# #### LASSO Regression

# %%
from sklearn.linear_model import Lasso
import matplotlib.pyplot as plt

# Reuse train/test split from previous linear model @ 80/20 train/test

# Train and fit the model
lasso = Lasso(alpha = .001, normalize = True)
lasso.fit(X_train, y_train)
lasso_pred = lasso.predict(X_test)
print('R2 =',lasso.score(X_test, y_test))
print('MAE =',metrics.mean_absolute_error(y_test, lasso_pred))
print('MSE = ',metrics.mean_squared_error(y_test, lasso_pred))
print('RMSE =',np.sqrt(metrics.mean_squared_error(y_test, lasso_pred)))

# Perform feature selection
print("")
lasso_coef = pd.Series(lasso.coef_, index = df2.drop('TOTALCHARGE',axis=1).columns)
print('Significant features:')
print(lasso_coef[lasso_coef > 0])
# Out:
# R2 = 0.28530603804714694
# MAE = 4.094758716692638
# MSE =  649.5902455694313
# RMSE = 25.4870603555889
#
# Significant features:
# TOTAL_CARTONS Test Prep                       169.477481
# TOTAL_LOOSE Test Prep                          99.278577
# TOTAL_PALLETS Trade                            44.628683
# TOTAL_UNITS Test Prep                         226.450734
# TOTAL UNITS Total                             713.209815
# COLLECT_METHOD_N                                3.871932
# CARRIER_CODE_FEDX                              27.495662
# CARRIER_CODE_UPSN                               1.925440
# SHIP_METHOD_FEDEX FREIGHT PPD                 275.769356
# SHIP_METHOD_FEDEX National Pre-Paid           531.055210
# SHIP_METHOD_FedEx Int'l Priority Prepaid       82.595636
# SHIP_METHOD_FedEx International Economy PP      9.714891
# SHIP_METHOD_Fedex Ground Bill Recipient        28.344594
# SHIP_METHOD_UPS 1-Day Air                      20.027992
# SHIP_METHOD_UPS 2-Day Air                      13.136557
# SHIP_METHOD_UPS Canada Int'l Saver Prepaid     61.307986
# SHIP_METHOD_UPS Freight Pre-Paid              131.584115
# SHIP_METHOD_UPS Ground                          3.740363
# SHIP_METHOD_UPS Next Day Sat. Delivery         34.830431
# SHIP_METHOD_UPS Puerto Rico 1-Day              71.069597
# SHIP_METHOD_UPS Puerto Rico 2-Day              90.024722
# FREIGHT_TYPE_Domestic Air Courier               1.198125
# SHIP_COUNTRY_NAME_Costa Rica                  106.748586
# SHIP_COUNTRY_NAME_Guatemala                   292.017370
# SHIP_COUNTRY_NAME_Iceland                     179.622200
# SHIP_COUNTRY_NAME_Panama                      108.602475
# SHIP_COUNTRY_NAME_Peru                         60.954398
# SHIP_COUNTRY_NAME_Puerto Rico                  15.676320
# REGION_Central & South America                  1.696168
# dtype: float64

# %% [markdown]
# Using a Lasso regression gives us an easier idea of feature selection by dropping certain variables for us.  From the above, we can tell that collect method, total units/loose/cartons/pallets, carrier code, ship method, freight type, and ship country and region are significant variables.  We can use this to further narrow down our features and run through the model again.

# %%
print('Significant variables =',np.array(lasso_coef[lasso_coef > 0].index))
print(df2.shape)
print(sum(y_pred))
print(sum(y_test))
# Out:
# Significant variables = ['TOTAL_CARTONS Test Prep' 'TOTAL_LOOSE Test Prep' 'TOTAL_PALLETS Trade'
#  'TOTAL_UNITS Test Prep' 'TOTAL UNITS Total' 'COLLECT_METHOD_N'
#  'CARRIER_CODE_FEDX' 'CARRIER_CODE_UPSN' 'SHIP_METHOD_FEDEX FREIGHT PPD'
#  'SHIP_METHOD_FEDEX National Pre-Paid'
#  "SHIP_METHOD_FedEx Int'l Priority Prepaid"
#  'SHIP_METHOD_FedEx International Economy PP'
#  'SHIP_METHOD_Fedex Ground Bill Recipient' 'SHIP_METHOD_UPS 1-Day Air'
#  'SHIP_METHOD_UPS 2-Day Air' "SHIP_METHOD_UPS Canada Int'l Saver Prepaid"
#  'SHIP_METHOD_UPS Freight Pre-Paid' 'SHIP_METHOD_UPS Ground'
#  'SHIP_METHOD_UPS Next Day Sat. Delivery'
#  'SHIP_METHOD_UPS Puerto Rico 1-Day' 'SHIP_METHOD_UPS Puerto Rico 2-Day'
#  'FREIGHT_TYPE_Domestic Air Courier' 'SHIP_COUNTRY_NAME_Costa Rica'
#  'SHIP_COUNTRY_NAME_Guatemala' 'SHIP_COUNTRY_NAME_Iceland'
#  'SHIP_COUNTRY_NAME_Panama' 'SHIP_COUNTRY_NAME_Peru'
#  'SHIP_COUNTRY_NAME_Puerto Rico']
# (419852, 417)
# [550982.54304443]
# [541640.98600003]

# %% [markdown]
# #### Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha = 0.1, normalize = True)
ridge.fit(X_train, y_train)
ridge_pred = ridge.predict(X_test)

print('R2 =',ridge.score(X_test, y_test))
print('MAE =',metrics.mean_absolute_error(y_test, ridge_pred))
print('MSE = ',metrics.mean_squared_error(y_test, ridge_pred))
print('RMSE =',np.sqrt(metrics.mean_squared_error(y_test, ridge_pred)))
# Out:
# R2 = 0.276617126410046
# MAE = 4.40365361211475
# MSE =  657.4876569714431
# RMSE = 25.64152212664925

# %% [markdown]
# We can see from the previous three examples that there isn't a huge amount of variation between basic, LASSO, and ridge regression, but our best RMSE definitely comes from the basic linear model.  It is interesting to see, however, that our best mean absolute error comes from the LASSO model.  Next, we'll do some feature selection and see how well we can improve our RMSE for this model.

# %% [markdown]
# #### Finalized Linear Regression

# %%
# Preprocessing
df3 = df1

# Scale continuous
scaler = pp.MinMaxScaler()
scaled1 = scaler.fit_transform(df2.iloc[:,10:51])
df3.iloc[:,10:51] = scaled1
scaled2 = scaler.fit_transform(df2.iloc[:,0:3])
df3.iloc[:,0:3] = scaled2

# Remove irrelevant variables
df3 = df3.drop(['CJDAT1','IHINDT','IHAEDT','INVOICENO','MARKET_OUTLET','CARRIER_CODE','PRIORITY_CODE','FREIGHT_TYPE'], axis=1)

# Generate dummy variables
df3 = pd.DataFrame(pd.get_dummies(df3))

# Test/train split at 80% train, 20% test
X2 = df3.drop('TOTALCHARGE',axis=1).values
y2 = df3['TOTALCHARGE'].values.reshape(-1,1)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size = 0.2, random_state=24)

# Fit & predict the model
linreg = linear_model.LinearRegression()
linreg.fit(X2_train, y2_train)
y2_pred = linreg.predict(X2_test)
print('R2 =',linreg.score(X2_test, y2_test),', which represents the % of the variance in the observed data can be explained by the model.')
# can also use: print(metrics.r2_score(y_test, y_pred))
print('MAE =',metrics.mean_absolute_error(y2_test, y2_pred))
print('MSE = ',metrics.mean_squared_error(y2_test, y2_pred))
print('RMSE =',np.sqrt(metrics.mean_squared_error(y2_test, y2_pred)))
# Out:
# R2 = 0.9998176662458134 , which represents the % of the variance in the observed data can be explained by the model.
# MAE = 0.0022092665570426365
# MSE =  0.16572440018109752
# RMSE = 0.4070926186767546

# %%
print(np.sum(y2_test))
print(np.sum(y2_pred))
# Out:
# 541640.986
# 541508.1954696729

# %% [markdown]
# In this case, we removed all of the date fields since all but the shipment date (IHAEDT) are essentially meaningless for this purpose, and we're already capturing shipment date in the ship month, which had a much higher coefficient originally than the exact dates.  We also removed market outlet, which never had a very high coefficient, and all freight-related variables *except* for ship method, which had some particularly high coefficients.  So that means freight type, carrier, and priority were removed.
#
#
# **Notes:
# Remove all original variables (dates, invoice nos, market outlet & all freight vars except ship method):**
# R2 = 0.9998176662458134 , which represents the % of the variance in the observed data can be explained by the model.
# MAE = 0.0022092665570426365
# MSE =  0.16572440018109752
# RMSE = 0.4070926186767546
#
# **Add back in freight type, for example:**
# R2 = 0.9336041702554276 , which represents the % of the variance in the observed data can be explained by the model.
# MAE = 0.046193192539711055
# MSE =  60.34762519990086
# RMSE = 7.768373394726908

# %%
print(df3.columns)
# Out:
# Index(['BOOK_WEIGHT Agency', 'BOOK_WEIGHT Education', 'BOOK_WEIGHT Reference',
#        'BOOK_WEIGHT Test Prep', 'BOOK_WEIGHT Trade', 'TOTAL_LINES Agency',
#        'TOTAL_LINES Education', 'TOTAL_LINES Reference',
#        'TOTAL_LINES Test Prep', 'TOTAL_LINES Trade',
#        ...
#        'SHIP_MONTH_2018-07', 'SHIP_MONTH_2018-08', 'SHIP_MONTH_2018-09',
#        'SHIP_MONTH_2018-10', 'SHIP_MONTH_2018-11', 'SHIP_MONTH_2018-12',
#        'SHIP_MONTH_2019-01', 'SHIP_MONTH_2019-02', 'SHIP_MONTH_2019-03',
#        'SHIP_MONTH_2019-04'],
#       dtype='object', length=325)
